# %% [markdown]
# # Identify tables with country, country and food, or other data
#
# The code goes through all the sample tables, determines its format and creates a dataframe with filenames and table number.

# %%
import os
import pandas as pd

# %%
# Define the directory containing the CSV files
directory = r'..\data\FAOSTAT\sample_data'

# %%
def process_csv_file(path):
    try:
        filename = os.path.basename(path)  # Mover esto fuera del bloque try para que esté disponible en except

        df = pd.read_csv(path, encoding_errors='replace') # Manejar errores de codificación reemplazando caracteres problemáticos

        table_nr = filename[:2]
        table_name_parts = filename.split('_')[1:4]
        table_name = '_'.join(table_name_parts)

        required_columns = ['Year', 'Area Code', 'Item']
        if not all(col in df.columns for col in required_columns):
            print(f"La tabla {filename} no tiene todas las columnas requeridas: {', '.join(required_columns)}")
            return {'table_type': "Otro/no_util", 'table_nr': table_nr, 'table_name': table_name}  # Return with "Otro/no_util"

        condition_paises = all(col in df.columns for col in ['Area Code', 'Year'])
        condition_comida = df['Item'].isin(['Meat of chickens; fresh or chilled', 'Tapioca of cassava', 'Wheat', 'Barley', 'Cattle']).any()

        if condition_paises and condition_comida:
            table_type = "Paises y comida"
        elif condition_paises:
            table_type = "Paises"
        elif condition_comida:
            table_type = "Solo comida"
        else:
            table_type = "Otro/no_util"

        return {'table_type': table_type, 'table_nr': table_nr, 'table_name': table_name}

    except UnicodeDecodeError:
        print(f"Error de codificación al leer la tabla {filename}. No se puede abrir.")
        return {'table_type': "Otro/no_util", 'table_nr': table_nr, 'table_name': table_name}  # Return with "Otro/no_util"

    except Exception as e:
        print(f"Error general al procesar la tabla {filename}: {e}")
        return None  # Return None for other errors

# Lista para almacenar las filas del DataFrame resultante
categories_rows = []

# Recursively walk through the directory and process CSV files
for root, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith('.csv'):
            path = os.path.join(root, filename)
            new_row = process_csv_file(path)  # Obtener la nueva fila
            if new_row is not None:  # Verificar si se obtuvo una fila válida
                categories_rows.append(new_row)  # Agregar la fila a la lista

# Crear el DataFrame final a partir de las filas recolectadas
categories_df = pd.DataFrame(categories_rows, columns=['table_type', 'table_nr', 'table_name'])
# Out:
# La tabla 10-sample_Development_Assistance_to_Agriculture_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 19-sample_Employment_Indicators_Agriculture_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 20-sample_Employment_Indicators_Rural_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 31-sample_Environment_Temperature_change_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 32-sample_Exchange_rate_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 35-sample_Food_Aid_Shipments_WFP_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 36-sample_Food_and_Diet_Individual_Quantitative_Dietary_Data_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 39-sample_Forestry_Trade_Flows_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 40-sample_Household_Consumption_and_Expenditure_Surveys_Food_and_Diet_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 41-sample_Indicators_from_Household_Surveys_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 42-sample_Individual_Quantitative_Dietary_Data_Food_and_Diet_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 57-sample_Minimum_Dietary_Diversity_for_Women_(MDD-W)_Food_and_Diet_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# La tabla 70-sample_Value_shares_industry_primary_factors_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item
# Error general al procesar la tabla 71-World_Census_Agriculture_E_All_Data_(Normalized).csv: Error tokenizing data. C error: Expected 15 fields in line 106, saw 17
#
# La tabla 65-sample_Supply_Utilization_Accounts_Food_and_Diet_E_All_Data_(Normalized).csv no tiene todas las columnas requeridas: Year, Area Code, Item

# %%
pd.set_option('display.max_rows', None)
categories_df
# Out:
#          table_type table_nr                                       table_name
# 0            Paises       01                              ASTI_Expenditures_E
# 1            Paises       02                               ASTI_Researchers_E
# 2            Paises       03                         Climate_change_Emissions
# 3            Paises       04              CommodityBalances_(non-food)_(-2013
# 4            Paises       05             CommodityBalances_(non-food)_(2010-)
# 5            Paises       06                   CommodityBalances_(non-food)_E
# 6            Paises       07                       ConsumerPriceIndices_E_All
# 7            Paises       08                       Cost_Affordability_Healthy
# 8            Paises       09                                  Deflators_E_All
# 9      Otro/no_util       10                        Development_Assistance_to
# 10           Paises       11                     Emissions_Agriculture_Energy
# 11  Paises y comida       12                                Emissions_crops_E
# 12           Paises       13                        Emissions_Drained_Organic
# 13           Paises       14                               Emissions_Land_Use
# 14           Paises       15                               Emissions_Land_Use
# 15  Paises y comida       16                            Emissions_livestock_E
# 16           Paises       17                               Emissions_Pre_Post
# 17           Paises       18                               Emissions_Totals_E
# 18     Otro/no_util       19                Employment_Indicators_Agriculture
# 19     Otro/no_util       20                      Employment_Indicators_Rural
# 20           Paises       21                    Environment_Cropland_nutrient
# 21           Paises       22                         Environment_Emissions_by
# 22           Paises       23                Environment_Emissions_intensities
# 23           Paises       24                           Environment_Food_Waste
# 24           Paises       25                          Environment_LandCover_E
# 25           Paises       26                            Environment_LandUse_E
# 26  Paises y comida       27                    Environment_LivestockManure_E
# 27  Paises y comida       28                  Environment_LivestockPatterns_E
# 28           Paises       29                         Environment_Pesticides_E
# 29           Paises       30                        Environment_Soil_nutrient
# 30     Otro/no_util       31                   Environment_Temperature_change
# 31     Otro/no_util       32                                  Exchange_rate_E
# 32           Paises       33                  FoodBalanceSheetsHistoric_E_All
# 33           Paises       34                          FoodBalanceSheets_E_All
# 34     Otro/no_util       35                               Food_Aid_Shipments
# 35     Otro/no_util       36                                    Food_and_Diet
# 36           Paises       37                               Food_Security_Data
# 37           Paises       38                                   Forestry_E_All
# 38     Otro/no_util       39                             Forestry_Trade_Flows
# 39     Otro/no_util       40                        Household_Consumption_and
# 40     Otro/no_util       41                        Indicators_from_Household
# 41     Otro/no_util       42                  Individual_Quantitative_Dietary
# 42           Paises       43                      Inputs_FertilizersArchive_E
# 43           Paises       44                     Inputs_FertilizersNutrient_E
# 44           Paises       45                      Inputs_FertilizersProduct_E
# 45           Paises       46                                 Inputs_LandUse_E
# 46           Paises       47                          Inputs_Pesticides_Trade
# 47           Paises       48                            Inputs_Pesticides_Use
# 48     Otro/no_util       57                        Minimum_Dietary_Diversity
# 49  Paises y comida       59                              PricesArchive_E_All
# 50           Paises       63                              SDG_BulkDownloads_E
# 51  Paises y comida       68                                  Trade_Indices_E
# 52     Otro/no_util       70                            Value_shares_industry
# 53  Paises y comida       64                              SUA_Crops_Livestock
# 54     Otro/no_util       65                      Supply_Utilization_Accounts
# 55           Paises       49                        Investment_CapitalStock_E
# 56           Paises       50  Investment_CountryInvestmentStatisticsProfile_E
# 57           Paises       51                   Investment_CreditAgriculture_E
# 58           Paises       52             Investment_ForeignDirectInvestment_E
# 59           Paises       53               Investment_GovernmentExpenditure_E
# 60           Paises       54                    Investment_MachineryArchive_E
# 61           Paises       55                           Investment_Machinery_E
# 62           Paises       56                  Macro-Statistics_Key_Indicators
# 63           Paises       58                                 Population_E_All
# 64  Paises y comida       60                                     Prices_E_All
# 65  Paises y comida       61                       Production_Crops_Livestock
# 66  Paises y comida       62                             Production_Indices_E
# 67  Paises y comida       66                           Trade_CropsLivestock_E
# 68  Paises y comida       69                              Value_of_Production

# %%
categories_df.to_csv(r'..\data\FAOSTAT\clean_data\all_tables_processed\all_tables_types.csv', index=False)

# %% [markdown]
# # Inspect only emission tables with food items
#
# We need to know in which FOOD ITEMS to focus

# %%
categories_df.query('table_type == "Paises y comida" & table_name.str.contains("Emissions|Environment")')
# Out:
#          table_type table_nr                       table_name
# 11  Paises y comida       12                Emissions_crops_E
# 15  Paises y comida       16            Emissions_livestock_E
# 26  Paises y comida       27    Environment_LivestockManure_E
# 27  Paises y comida       28  Environment_LivestockPatterns_E
