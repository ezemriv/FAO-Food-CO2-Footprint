# %%
import pandas as pd
# import numpy as np

# %%
df = pd.read_parquet(r"..\data\FAOSTAT\clean_data\all_tables_processed\all_tables_processed\full_country_dataset_v1.parquet")

# %%
df.head()
# Out:
#    Area Code     Area  Year  Total_Energy_Emissions_(CH4)_kt  \
# 0          1  Armenia  1990                              NaN
# 1          1  Armenia  1991                              NaN
# 2          1  Armenia  1992                           0.0300
# 3          1  Armenia  1993                           0.0077
# 4          1  Armenia  1994                           0.0081
#
#    Total_Energy_Emissions_(CO2)_kt  Total_Energy_Emissions_(N2O)_kt  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                         734.6265                           0.0179
# 3                          90.3345                           0.0093
# 4                          95.1042                           0.0080
#
#    Total_Energy_Energy_use_in_agriculture_TJ  Cropland_organic_soils_Area_ha  \
# 0                                        NaN                             NaN
# ...
