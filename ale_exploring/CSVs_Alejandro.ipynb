# %% [markdown]
# # **EDA 37 to 54**
#
# I have downloaded all data from https://www.fao.org/faostat/en/#home --> "Bulk Download"
# I will inspect tables related to "emissions"

# %%
import pandas as pd
import re
import glob


# for EDA
from ydata_profiling import ProfileReport

# %%
def read_CSV (numero):

    pattern = f"data/sample_data/{numero}-*All_Data_(Normalized).csv"
    matching_files = glob.glob(pattern)
    
    if not matching_files:
        print("No existe el archivo")
        return None, None
    
    # Selecciona el primer archivo que coincida con el patrón
    full_path = matching_files[0]
    
    try:
        df = pd.read_csv(full_path)
    except Exception as e:
        print(f"Error al leer el archivo: {e}")
        return None, None
    

    return df

# %% [markdown]
# ## 37-sample_Food_Security_Data_E_All_Data_(Normalized).csv

# %%
df_37 = read_CSV(11)
df_37.sample(5)
# Out:
#        Area Code Area Code (M49)           Area  Item Code  \
# 18999        181            '716       Zimbabwe       6809
# 10771        216            '764       Thailand       6812
# 11794       5102            '017  Middle Africa       6813
# 3011         184            '646         Rwanda       6813
# 13542        230            '804        Ukraine       6812
#
#                                         Item  Element Code  \
# 18999                                   Coal          7230
# 10771  Total Energy (excl.eletricity & heat)          7273
# 11794                           Total Energy          7225
# 3011                            Total Energy         72184
# 13542  Total Energy (excl.eletricity & heat)          7273
#
#                          Element  Year Code  Year Unit      Value Flag
# 18999            Emissions (N2O)       1989  1989   kt     0.0540    A
# 10771            Emissions (CO2)       1999  1999   kt  6749.9623    A
# ...

# %%
print(df_37["Item"].unique())
print(df_37["Element"].unique())
# Out:
# ['Domestic wastewater' 'Solid food waste' 'Waste - agri-food systems'
#  'Incineration' 'Industrial wastewater']
# ['Emissions (CH4)' 'Emissions (N2O)' 'Emissions (CO2)']

# %%
df_37.groupby("Item")["Element"].value_counts().to_frame()
# Out:
#                                                                  count
# Item                                  Element
# Coal                                  Energy use in agriculture    380
#                                       Emissions (CO2)              249
#                                       Emissions (N2O)              245
#                                       Emissions (CH4)              234
# Electricity                           Energy use in agriculture   1011
#                                       Emissions (CO2)              974
#                                       Emissions (CH4)              929
#                                       Emissions (N2O)              843
# Heat                                  Emissions (CO2)              206
#                                       Energy use in agriculture    202
#                                       Emissions (CH4)              196
#                                       Emissions (N2O)              185
# ...

# %% [markdown]
# ## 38-sample_Forestry_E_All_Data_(Normalized).csv

# %%
df_38 = read_CSV(38)
df_38.sample(2)
# Out:
#        Area Code Area Code (M49)        Area  Item Code               Item  \
# 904           39            '148        Chad       1872           Sawnwood
# 14973        135            '474  Martinique       1873  Wood-based panels
#
#        Element Code       Element  Year Code  Year      Unit  Value Flag Note
# 904            5622  Import Value       2022  2022  1000 USD    0.0    E  NaN
# 14973          5922  Export Value       2002  2002  1000 USD    0.0    E  NaN

# %% [markdown]
# ## 40 Household Consumption and Expenditure Surveys Food and Diet

# %%
df_40 = read_CSV(46)
df_40.head(2)
# Out:
#    Area Code Area Code (M49)              Area  Item Code  \
# 0         70            '258  French Polynesia       6655
# 1        125            '438     Liechtenstein       6620
#
#                              Item  Element Code Element  Year Code  Year  \
# 0  Permanent meadows and pastures          5110    Area       2008  2008
# 1                        Cropland          5110    Area       1969  1969
#
#       Unit  Value Flag  Note
# 0  1000 ha   20.0    I   NaN
# 1  1000 ha    4.0    A   NaN

# %% [markdown]
# ## 46 Land Use

# %%
df_40 = read_CSV(46)
df_40.sample(10)
# Out:
#        Area Code Area Code (M49)                  Area  Item Code  \
# 16412        212            '760  Syrian Arab Republic       6620
# 335          130            '454                Malawi       6620
# 11561        144            '508            Mozambique       6671
# 11612       5000            '001                 World       6610
# 10216        207            '740              Suriname       6690
# 6889         136            '478            Mauritania       6621
# 13788       5404            '155        Western Europe       6621
# 3422         106            '380                 Italy       6646
# 11528         79            '276               Germany       6655
# 16456       5503            '057            Micronesia       6620
#
#                                         Item  Element Code  \
# 16412                               Cropland          7208
# 335                                 Cropland          7208
# 11561  Agriculture area under organic agric.          7208
# ...
