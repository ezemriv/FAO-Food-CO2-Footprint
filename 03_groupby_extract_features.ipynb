# %% [markdown]
# # Script para extraer datos utiles de cada tabla desde el formato zip directamente

# %%
import pandas as pd
import numpy as np
import zipfile
import io

#supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
zip_path = r'.\data\FAOSTAT\all_raw\16-sample_Emissions_livestock_E_All_Data_(Normalized).zip'

# %% [markdown]
# ### Abrir el CSV dentro del zip file que incluye el patron "All_Data_" y guardarlo en un dataframe

# %%
# Initialize an empty DataFrame
df = pd.DataFrame()

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List all files in the zip archive
    all_files = zip_ref.namelist()
    print("Files in the zip archive:", all_files)
    
    # Iterate through the file names in the zip archive
    for file_name in all_files:
        # Check if the file name contains the pattern "All_Data_"
        if "All_Data_" in file_name and file_name.endswith(".csv"):
            print(f"Found matching file: {file_name}")
            # Read the CSV file into a DataFrame
            with zip_ref.open(file_name) as file:
                temp_df = pd.read_csv(file, encoding = "ISO-8859-1")
                # Concatenate the data from this CSV to the main DataFrame
                df = pd.concat([df, temp_df], ignore_index=True)
# Out:
# Files in the zip archive: ['Emissions_livestock_E_All_Data_(Normalized).csv', 'Emissions_livestock_E_AreaCodes.csv', 'Emissions_livestock_E_Flags.csv', 'Emissions_livestock_E_ItemCodes.csv']
# Found matching file: Emissions_livestock_E_All_Data_(Normalized).csv

# %% [markdown]
# ### Determinar si es una tabla de PAISES, COMIDAS, MIXTA o OTRAS
#
# (mirando bien creo que no hay tablas solo de comidas)

# %%
condition_paises = all(col in df.columns for col in ['Area Code', 'Year'])
condition_comida = df['Item'].isin(['Meat of chickens; fresh or chilled', 'Tapioca of cassava', 'Wheat', 'Barley', 'Cattle']).any()

if condition_paises and not condition_comida:
    print("La tabla parece ser SOLO de PAISES")
elif condition_comida and condition_paises:
    print("La tabla parece ser de COMIDAS (comidas, cultivos o animales) Y PAISES")
else:
    print("Ni idea que es esta tabla")
# Out:
# La tabla parece ser de COMIDAS (comidas, cultivos o animales) Y PAISES

# %%
df.sample(10)
# Out:
#          Area Code Area Code (M49)                              Area  \
# 54112            3            '008                           Albania
# 1502314         61            '226                 Equatorial Guinea
# 5400524       5204            '013                   Central America
# 696633          29            '108                           Burundi
# 6071402       5802            '432  Land Locked Developing Countries
# 4109273        200            '702                         Singapore
# 4288567         38            '144                         Sri Lanka
# 894381         351            '159                             China
# 3755106        146            '498               Republic of Moldova
# 208211          10            '036                         Australia
#
#          Item Code Item Code (CPC)                Item  Element Code  \
# 54112         1749          'F1749     Sheep and Goats         72300
# 1502314       1053          'F1053  Chickens, broilers        723811
# 5400524        976          '02122               Sheep         72254
# 696633        2029          'F2029       Poultry Birds        723812
# 6071402       1749          'F1749     Sheep and Goats         72360
# 4109273       1053          'F1053  Chickens, broilers         72431
# 4288567       1755          'F1755         All Animals         72306
# 894381         960          'F0960       Cattle, dairy         72360
# 3755106        961          'F0961   Cattle, non-dairy        723802
# 208211        1079          '02152             Turkeys         72341
#
#                                                    Element  Year Code  Year  \
# 54112               Manure left on pasture (Emissions N2O)       2009  2009
# 1502314  Manure applied to soils that volatilises (N co...       1996  1996
# 5400524               Enteric fermentation (Emissions CH4)       2050  2050
# 696633    Manure applied to soils that leaches (N content)       1970  1970
# 6071402    Manure left on pasture (Indirect emissions N2O)       1968  1968
# 4109273                    Livestock total (Emissions N2O)       1983  1983
# 4288567                  Manure management (Emissions N2O)       1998  1998
# 894381     Manure left on pasture (Indirect emissions N2O)       2006  2006
# 3755106    Manure left on pasture that leaches (N content)       2009  2009
# 208211      Manure applied to soils (Direct emissions N2O)       1965  1965
#
#          Source Code      Source Unit        Value Flag Note
# 54112           3050  FAO TIER 1   kt       0.8168    E  NaN
# 1502314         3050  FAO TIER 1   kg    2938.4982    E  NaN
# 5400524         3050  FAO TIER 1   kt      49.1449    F  NaN
# 696633          3050  FAO TIER 1   kg   52353.7020    E  NaN
# 6071402         3050  FAO TIER 1   kt       7.8075    E  NaN
# 4109273         3050  FAO TIER 1   kt       0.0020    E  NaN
# 4288567         3050  FAO TIER 1   kt       0.0654    E  NaN
# 894381          3050  FAO TIER 1   kt       1.1622    E  NaN
# 3755106         3050  FAO TIER 1   kg  172127.5625    E  NaN
# 208211          3050  FAO TIER 1   kt       0.0053    E  NaN

# %% [markdown]
# Ver las diferentes combinaciones de item y element que hay

# %%
pd.set_option('display.max_rows', None)
df.groupby('Item')['Element'].value_counts().to_frame().sort_values(by = 'count', ascending=False)
# Out:
#                                                                        count
# Item               Element
# All Animals        Livestock total (Emissions CH4)                     16208
#                    Manure management (Emissions CH4)                   16123
#                    Enteric fermentation (Emissions CH4)                16121
#                    Livestock total (Emissions N2O)                     16012
#                    Manure management (Emissions N2O)                   16012
#                    Manure applied to soils (Direct emissions N2O)      15435
#                    Manure applied to soils (N content)                 15434
#                    Manure management (Direct emissions N2O)            15422
# Poultry Birds      Stocks                                              15398
# All Animals        Manure management (manure treated, N content)       15372
# Poultry Birds      Manure management (Direct emissions N2O)            15277
#                    Manure management (manure treated, N content)       15277
# Cattle, non-dairy  Stocks                                              15215
# Cattle             Stocks                                              15186
# Cattle, non-dairy  Livestock total (Emissions CH4)                     15165
#                    Enteric fermentation (Emissions CH4)                15164
# Cattle             Livestock total (Emissions CH4)                     15157
#                    Enteric fermentation (Emissions CH4)                15157
#                    Manure management (manure treated, N content)       15089
#                    Manure management (Direct emissions N2O)            15058
# Cattle, non-dairy  Manure management (manure treated, N content)       15058
#                    Manure management (Direct emissions N2O)            15058
# Cattle             Manure left on pasture (N content)                  15027
# Cattle, non-dairy  Manure left on pasture (N content)                  15027
# Cattle, dairy      Stocks                                              14939
# Sheep and Goats    Stocks                                              14875
# Cattle, dairy      Livestock total (Emissions CH4)                     14866
#                    Enteric fermentation (Emissions CH4)                14865
# Sheep and Goats    Enteric fermentation (Emissions CH4)                14818
#                    Livestock total (Emissions CH4)                     14818
# Cattle, dairy      Manure management (manure treated, N content)       14818
#                    Manure management (Direct emissions N2O)            14787
#                    Manure left on pasture (N content)                  14720
# Sheep and Goats    Manure left on pasture (N content)                  14720
#                    Manure management (manure treated, N content)       14689
#                    Manure management (Direct emissions N2O)            14689
# Poultry Birds      Manure left on pasture (N content)                  14686
# Goats              Stocks                                              14649
#                    Livestock total (Emissions CH4)                     14526
#                    Enteric fermentation (Emissions CH4)                14526
#                    Manure management (Direct emissions N2O)            14364
#                    Manure left on pasture (N content)                  14364
#                    Manure management (manure treated, N content)       14364
# Sheep              Stocks                                              14310
# Swine              Stocks                                              14303
# All Animals        Manure left on pasture (Direct emissions N2O)       14261
# Swine              Livestock total (Emissions CH4)                     14241
#                    Enteric fermentation (Emissions CH4)                14240
# All Animals        Manure management (Indirect emissions N2O)          14238
# Sheep              Livestock total (Emissions CH4)                     14218
#                    Enteric fermentation (Emissions CH4)                14217
# All Animals        Manure left on pasture (N content)                  14215
#                    Indirect emissions (N2O that leaches) (Manure o...  14207
#                    Manure applied to soils (Indirect emissions N2O)    14207
#                    Indirect emissions (N2O that volatilises) (Manu...  14207
#                    Manure applied to soils that volatilises (N con...  14207
#                    Manure left on pasture (Emissions N2O)              14207
#                    Manure left on pasture (Indirect emissions N2O)     14207
#                    Manure applied to soils that leaches (N content)    14207
#                    Emissions (N2O) (Manure applied)                    14207
#                    Indirect emissions (N2O that leaches) (Manure a...  14207
#                    Indirect emissions (N2O that volatilises) (Manu...  14207
#                    Manure left on pasture that leaches (N content)     14207
#                    Manure left on pasture that volatilises (N cont...  14207
# Poultry Birds      Livestock total (Emissions CH4)                     14156
#                    Manure management (Emissions CH4)                   14156
# Swine              Manure management (manure treated, N content)       14148
# Poultry Birds      Livestock total (Emissions N2O)                     14119
#                    Manure management (Emissions N2O)                   14119
# Chickens, broilers Stocks                                              14097
# Chickens, layers   Stocks                                              14097
# Chickens           Stocks                                              14092
# Swine              Manure management (Direct emissions N2O)            14086
# Chickens, broilers Manure left on pasture (Emissions N2O)              14081
# Chickens, layers   Indirect emissions (N2O that leaches) (Manure a...  14081
# Chickens           Manure left on pasture (Indirect emissions N2O)     14081
#                    Manure left on pasture (Emissions N2O)              14081
#                    Manure left on pasture (Direct emissions N2O)       14081
#                    Manure applied to soils that volatilises (N con...  14081
#                    Manure applied to soils that leaches (N content)    14081
#                    Manure applied to soils (N content)                 14081
#                    Manure applied to soils (Indirect emissions N2O)    14081
#                    Manure applied to soils (Direct emissions N2O)      14081
#                    Livestock total (Emissions N2O)                     14081
# Chickens, layers   Emissions (N2O) (Manure applied)                    14081
#                    Indirect emissions (N2O that leaches) (Manure o...  14081
# Chickens           Manure left on pasture that leaches (N content)     14081
# Chickens, layers   Indirect emissions (N2O that volatilises) (Manu...  14081
# Chickens           Livestock total (Emissions CH4)                     14081
#                    Indirect emissions (N2O that volatilises) (Manu...  14081
#                    Indirect emissions (N2O that volatilises) (Manu...  14081
#                    Indirect emissions (N2O that leaches) (Manure o...  14081
#                    Indirect emissions (N2O that leaches) (Manure a...  14081
# Chickens, layers   Indirect emissions (N2O that volatilises) (Manu...  14081
#                    Livestock total (Emissions CH4)                     14081
#                    Manure applied to soils that leaches (N content)    14081
#                    Livestock total (Emissions N2O)                     14081
#                    Manure applied to soils (Direct emissions N2O)      14081
# Chickens           Manure left on pasture (N content)                  14081
#                    Manure left on pasture that volatilises (N cont...  14081
# Chickens, broilers Manure left on pasture (Direct emissions N2O)       14081
# Chickens           Manure management (Direct emissions N2O)            14081
# Chickens, broilers Manure applied to soils that volatilises (N con...  14081
#                    Manure applied to soils that leaches (N content)    14081
#                    Manure applied to soils (N content)                 14081
#                    Manure applied to soils (Indirect emissions N2O)    14081
#                    Manure applied to soils (Direct emissions N2O)      14081
#                    Livestock total (Emissions N2O)                     14081
#                    Livestock total (Emissions CH4)                     14081
#                    Indirect emissions (N2O that volatilises) (Manu...  14081
#                    Indirect emissions (N2O that volatilises) (Manu...  14081
#                    Indirect emissions (N2O that leaches) (Manure o...  14081
#                    Indirect emissions (N2O that leaches) (Manure a...  14081
#                    Emissions (N2O) (Manure applied)                    14081
# Chickens, layers   Manure applied to soils (N content)                 14081
# Chickens           Manure management (manure treated, N content)       14081
#                    Manure management (Indirect emissions N2O)          14081
# Chickens, broilers Manure left on pasture (Indirect emissions N2O)     14081
#                    Manure left on pasture (N content)                  14081
#                    Manure left on pasture that leaches (N content)     14081
#                    Manure left on pasture that volatilises (N cont...  14081
#                    Manure management (Direct emissions N2O)            14081
#                    Manure management (Emissions CH4)                   14081
# Chickens           Manure management (Emissions N2O)                   14081
# Chickens, broilers Manure management (Emissions N2O)                   14081
#                    Manure management (Indirect emissions N2O)          14081
#                    Manure management (manure treated, N content)       14081
# Chickens           Manure management (Emissions CH4)                   14081
# Chickens, layers   Manure applied to soils (Indirect emissions N2O)    14081
#                    Manure management (Emissions N2O)                   14081
# Poultry Birds      Manure left on pasture that leaches (N content)     14081
# Chickens, layers   Manure left on pasture (N content)                  14081
#                    Manure left on pasture that leaches (N content)     14081
#                    Manure left on pasture that volatilises (N cont...  14081
#                    Manure management (Direct emissions N2O)            14081
#                    Manure management (Emissions CH4)                   14081
#                    Manure left on pasture (Direct emissions N2O)       14081
#                    Manure applied to soils that volatilises (N con...  14081
#                    Manure management (Indirect emissions N2O)          14081
#                    Manure management (manure treated, N content)       14081
#                    Manure left on pasture (Emissions N2O)              14081
# Poultry Birds      Manure left on pasture that volatilises (N cont...  14081
#                    Manure management (Indirect emissions N2O)          14081
#                    Manure left on pasture (Indirect emissions N2O)     14081
#                    Manure left on pasture (Emissions N2O)              14081
#                    Indirect emissions (N2O that leaches) (Manure a...  14081
#                    Indirect emissions (N2O that leaches) (Manure o...  14081
#                    Indirect emissions (N2O that volatilises) (Manu...  14081
#                    Indirect emissions (N2O that volatilises) (Manu...  14081
#                    Manure applied to soils (Direct emissions N2O)      14081
#                    Manure applied to soils (Indirect emissions N2O)    14081
#                    Manure applied to soils (N content)                 14081
# Chickens, layers   Manure left on pasture (Indirect emissions N2O)     14081
# Poultry Birds      Manure applied to soils that leaches (N content)    14081
#                    Manure applied to soils that volatilises (N con...  14081
#                    Manure left on pasture (Direct emissions N2O)       14081
# Sheep              Manure left on pasture (N content)                  14055
#                    Manure management (manure treated, N content)       14024
#                    Manure management (Direct emissions N2O)            14024
# Cattle, non-dairy  Manure management (Emissions CH4)                   13936
# Cattle             Manure management (Emissions CH4)                   13929
#                    Manure management (Emissions N2O)                   13924
#                    Livestock total (Emissions N2O)                     13924
# Cattle, dairy      Manure management (Emissions CH4)                   13910
# Cattle, non-dairy  Manure management (Emissions N2O)                   13906
#                    Livestock total (Emissions N2O)                     13906
# Cattle, dairy      Livestock total (Emissions N2O)                     13906
#                    Manure management (Emissions N2O)                   13906
# Cattle, non-dairy  Indirect emissions (N2O that leaches) (Manure o...  13862
#                    Manure applied to soils (N content)                 13862
#                    Indirect emissions (N2O that volatilises) (Manu...  13862
#                    Manure applied to soils (Direct emissions N2O)      13862
#                    Manure applied to soils (Indirect emissions N2O)    13862
#                    Manure applied to soils that leaches (N content)    13862
#                    Manure applied to soils that volatilises (N con...  13862
#                    Manure left on pasture (Direct emissions N2O)       13862
#                    Manure left on pasture (Indirect emissions N2O)     13862
#                    Manure left on pasture that leaches (N content)     13862
#                    Manure left on pasture that volatilises (N cont...  13862
#                    Manure management (Indirect emissions N2O)          13862
#                    Indirect emissions (N2O that volatilises) (Manu...  13862
#                    Manure left on pasture (Emissions N2O)              13862
#                    Indirect emissions (N2O that leaches) (Manure a...  13862
# Cattle             Manure left on pasture (Direct emissions N2O)       13862
# Cattle, non-dairy  Emissions (N2O) (Manure applied)                    13862
# Cattle             Manure left on pasture that volatilises (N cont...  13862
# Cattle, dairy      Emissions (N2O) (Manure applied)                    13862
#                    Indirect emissions (N2O that leaches) (Manure a...  13862
#                    Indirect emissions (N2O that leaches) (Manure o...  13862
#                    Indirect emissions (N2O that volatilises) (Manu...  13862
#                    Indirect emissions (N2O that volatilises) (Manu...  13862
#                    Manure applied to soils (Direct emissions N2O)      13862
#                    Manure applied to soils (Indirect emissions N2O)    13862
#                    Manure applied to soils (N content)                 13862
#                    Manure applied to soils that leaches (N content)    13862
#                    Manure applied to soils that volatilises (N con...  13862
# Cattle             Manure left on pasture that leaches (N content)     13862
#                    Manure left on pasture (Indirect emissions N2O)     13862
#                    Manure left on pasture (Emissions N2O)              13862
#                    Manure applied to soils that volatilises (N con...  13862
# Cattle, dairy      Manure left on pasture that volatilises (N cont...  13862
# Cattle             Indirect emissions (N2O that leaches) (Manure a...  13862
#                    Indirect emissions (N2O that leaches) (Manure o...  13862
#                    Indirect emissions (N2O that volatilises) (Manu...  13862
#                    Indirect emissions (N2O that volatilises) (Manu...  13862
#                    Manure applied to soils (Direct emissions N2O)      13862
# Cattle, dairy      Manure management (Indirect emissions N2O)          13862
# Cattle             Manure applied to soils (Indirect emissions N2O)    13862
# Cattle, dairy      Manure left on pasture that leaches (N content)     13862
#                    Manure left on pasture (Indirect emissions N2O)     13862
#                    Manure left on pasture (Emissions N2O)              13862
#                    Manure left on pasture (Direct emissions N2O)       13862
# Cattle             Manure applied to soils (N content)                 13862
#                    Manure applied to soils that leaches (N content)    13862
#                    Manure management (Indirect emissions N2O)          13862
# Sheep and Goats    Manure management (Emissions CH4)                   13591
#                    Livestock total (Emissions N2O)                     13561
#                    Manure management (Emissions N2O)                   13561
#                    Indirect emissions (N2O that leaches) (Manure o...  13555
#                    Indirect emissions (N2O that volatilises) (Manu...  13555
#                    Indirect emissions (N2O that leaches) (Manure a...  13555
#                    Manure applied to soils that volatilises (N con...  13555
#                    Manure applied to soils that leaches (N content)    13555
#                    Manure applied to soils (N content)                 13555
#                    Manure applied to soils (Indirect emissions N2O)    13555
#                    Manure applied to soils (Direct emissions N2O)      13555
#                    Indirect emissions (N2O that volatilises) (Manu...  13555
#                    Manure left on pasture (Direct emissions N2O)       13555
#                    Manure left on pasture (Emissions N2O)              13555
#                    Manure left on pasture (Indirect emissions N2O)     13555
#                    Manure left on pasture that leaches (N content)     13555
#                    Manure left on pasture that volatilises (N cont...  13555
#                    Manure management (Indirect emissions N2O)          13555
# Goats              Manure management (Emissions CH4)                   13329
# Horses             Stocks                                              13286
# Goats              Livestock total (Emissions N2O)                     13266
#                    Manure management (Emissions N2O)                   13266
# Swine              Manure left on pasture (N content)                  13238
# Goats              Manure management (Indirect emissions N2O)          13230
#                    Manure applied to soils (N content)                 13230
#                    Indirect emissions (N2O that leaches) (Manure o...  13230
#                    Indirect emissions (N2O that volatilises) (Manu...  13230
#                    Indirect emissions (N2O that volatilises) (Manu...  13230
#                    Manure applied to soils (Direct emissions N2O)      13230
#                    Manure applied to soils (Indirect emissions N2O)    13230
#                    Manure applied to soils that volatilises (N con...  13230
#                    Manure applied to soils that leaches (N content)    13230
#                    Indirect emissions (N2O that leaches) (Manure a...  13230
#                    Manure left on pasture (Direct emissions N2O)       13230
#                    Manure left on pasture (Emissions N2O)              13230
#                    Manure left on pasture that leaches (N content)     13230
#                    Manure left on pasture that volatilises (N cont...  13230
#                    Emissions (N2O) (Manure applied)                    13230
#                    Manure left on pasture (Indirect emissions N2O)     13230
# Horses             Livestock total (Emissions CH4)                     13172
#                    Enteric fermentation (Emissions CH4)                13171
#                    Manure left on pasture (N content)                  13049
# Swine              Manure management (Emissions CH4)                   13013
# Swine, breeding    Stocks                                              12994
# Sheep              Manure management (Emissions CH4)                   12990
# Horses             Manure management (Direct emissions N2O)            12987
#                    Manure management (manure treated, N content)       12987
# Swine, breeding    Livestock total (Emissions CH4)                     12980
#                    Manure management (manure treated, N content)       12980
#                    Manure management (Direct emissions N2O)            12980
#                    Enteric fermentation (Emissions CH4)                12980
# Swine              Livestock total (Emissions N2O)                     12952
# Swine, breeding    Manure left on pasture (N content)                  12952
# Swine              Manure management (Emissions N2O)                   12952
# Swine, market      Stocks                                              12936
# Sheep              Livestock total (Emissions N2O)                     12931
#                    Manure management (Emissions N2O)                   12931
# Swine, breeding    Manure applied to soils that volatilises (N con...  12921
# Swine, market      Manure management (manure treated, N content)       12921
# Swine, breeding    Manure left on pasture (Indirect emissions N2O)     12921
#                    Manure left on pasture (Direct emissions N2O)       12921
#                    Manure management (Indirect emissions N2O)          12921
#                    Manure left on pasture that leaches (N content)     12921
#                    Manure management (Emissions CH4)                   12921
#                    Manure left on pasture (Emissions N2O)              12921
#                    Manure left on pasture that volatilises (N cont...  12921
#                    Manure management (Emissions N2O)                   12921
# Swine, market      Manure management (Indirect emissions N2O)          12921
# Swine, breeding    Manure applied to soils (N content)                 12921
# Swine, market      Manure management (Emissions N2O)                   12921
#                    Indirect emissions (N2O that leaches) (Manure a...  12921
#                    Enteric fermentation (Emissions CH4)                12921
#                    Emissions (N2O) (Manure applied)                    12921
#                    Indirect emissions (N2O that volatilises) (Manu...  12921
#                    Livestock total (Emissions CH4)                     12921
#                    Livestock total (Emissions N2O)                     12921
#                    Manure applied to soils (Direct emissions N2O)      12921
#                    Manure applied to soils (Indirect emissions N2O)    12921
#                    Manure applied to soils (N content)                 12921
#                    Manure applied to soils that leaches (N content)    12921
#                    Manure applied to soils that volatilises (N con...  12921
#                    Manure left on pasture (Direct emissions N2O)       12921
#                    Manure left on pasture (Emissions N2O)              12921
#                    Manure left on pasture (Indirect emissions N2O)     12921
#                    Manure left on pasture (N content)                  12921
#                    Manure left on pasture that leaches (N content)     12921
#                    Manure left on pasture that volatilises (N cont...  12921
#                    Manure management (Direct emissions N2O)            12921
#                    Manure management (Emissions CH4)                   12921
# Swine, breeding    Manure applied to soils that leaches (N content)    12921
#                    Indirect emissions (N2O that leaches) (Manure o...  12921
#                    Manure applied to soils (Indirect emissions N2O)    12921
#                    Manure applied to soils (Direct emissions N2O)      12921
# Swine              Indirect emissions (N2O that leaches) (Manure a...  12921
#                    Indirect emissions (N2O that leaches) (Manure o...  12921
#                    Indirect emissions (N2O that volatilises) (Manu...  12921
#                    Indirect emissions (N2O that volatilises) (Manu...  12921
#                    Manure applied to soils (Direct emissions N2O)      12921
#                    Manure applied to soils (Indirect emissions N2O)    12921
#                    Manure applied to soils (N content)                 12921
#                    Manure applied to soils that leaches (N content)    12921
#                    Manure applied to soils that volatilises (N con...  12921
#                    Manure left on pasture (Direct emissions N2O)       12921
#                    Manure left on pasture (Emissions N2O)              12921
#                    Manure left on pasture (Indirect emissions N2O)     12921
# Swine, market      Indirect emissions (N2O that leaches) (Manure o...  12921
# Swine, breeding    Livestock total (Emissions N2O)                     12921
#                    Indirect emissions (N2O that volatilises) (Manu...  12921
#                    Indirect emissions (N2O that volatilises) (Manu...  12921
# Swine, market      Indirect emissions (N2O that volatilises) (Manu...  12921
# Swine, breeding    Indirect emissions (N2O that leaches) (Manure a...  12921
#                    Emissions (N2O) (Manure applied)                    12921
# Swine              Manure management (Indirect emissions N2O)          12921
#                    Manure left on pasture that volatilises (N cont...  12921
#                    Manure left on pasture that leaches (N content)     12921
# Sheep              Indirect emissions (N2O that volatilises) (Manu...  12890
#                    Indirect emissions (N2O that leaches) (Manure a...  12890
#                    Emissions (N2O) (Manure applied)                    12890
#                    Indirect emissions (N2O that leaches) (Manure o...  12890
#                    Manure applied to soils (Direct emissions N2O)      12890
#                    Manure management (Indirect emissions N2O)          12890
#                    Manure left on pasture that volatilises (N cont...  12890
#                    Manure left on pasture that leaches (N content)     12890
#                    Manure left on pasture (Indirect emissions N2O)     12890
#                    Manure left on pasture (Emissions N2O)              12890
#                    Manure left on pasture (Direct emissions N2O)       12890
#                    Indirect emissions (N2O that volatilises) (Manu...  12890
#                    Manure applied to soils that leaches (N content)    12890
#                    Manure applied to soils (N content)                 12890
#                    Manure applied to soils (Indirect emissions N2O)    12890
#                    Manure applied to soils that volatilises (N con...  12890
# Horses             Manure management (Emissions CH4)                   11975
#                    Livestock total (Emissions N2O)                     11913
#                    Manure management (Emissions N2O)                   11913
#                    Manure applied to soils (Direct emissions N2O)      11884
#                    Manure left on pasture that volatilises (N cont...  11884
#                    Emissions (N2O) (Manure applied)                    11884
#                    Indirect emissions (N2O that leaches) (Manure a...  11884
#                    Indirect emissions (N2O that leaches) (Manure o...  11884
#                    Indirect emissions (N2O that volatilises) (Manu...  11884
#                    Indirect emissions (N2O that volatilises) (Manu...  11884
#                    Manure management (Indirect emissions N2O)          11884
#                    Manure applied to soils (Indirect emissions N2O)    11884
#                    Manure applied to soils that leaches (N content)    11884
#                    Manure applied to soils that volatilises (N con...  11884
#                    Manure left on pasture (Direct emissions N2O)       11884
#                    Manure left on pasture (Emissions N2O)              11884
#                    Manure left on pasture (Indirect emissions N2O)     11884
#                    Manure left on pasture that leaches (N content)     11884
#                    Manure applied to soils (N content)                 11884
# Mules and Asses    Stocks                                              10285
#                    Livestock total (Emissions CH4)                     10250
#                    Enteric fermentation (Emissions CH4)                10250
#                    Manure left on pasture (N content)                  10134
#                    Manure management (Direct emissions N2O)            10099
#                    Manure management (manure treated, N content)       10099
#                    Manure management (Emissions CH4)                    9616
#                    Livestock total (Emissions N2O)                      9583
#                    Manure management (Emissions N2O)                    9583
#                    Manure applied to soils that leaches (N content)     9559
#                    Manure left on pasture that volatilises (N cont...   9559
#                    Manure left on pasture that leaches (N content)      9559
#                    Manure left on pasture (Indirect emissions N2O)      9559
#                    Manure left on pasture (Emissions N2O)               9559
#                    Manure left on pasture (Direct emissions N2O)        9559
#                    Manure applied to soils that volatilises (N con...   9559
#                    Manure management (Indirect emissions N2O)           9559
#                    Manure applied to soils (N content)                  9559
#                    Manure applied to soils (Indirect emissions N2O)     9559
#                    Manure applied to soils (Direct emissions N2O)       9559
#                    Indirect emissions (N2O that volatilises) (Manu...   9559
#                    Indirect emissions (N2O that volatilises) (Manu...   9559
#                    Indirect emissions (N2O that leaches) (Manure o...   9559
#                    Indirect emissions (N2O that leaches) (Manure a...   9559
# Asses              Stocks                                               9324
#                    Manure left on pasture (Indirect emissions N2O)      9281
#                    Manure management (manure treated, N content)        9281
#                    Manure applied to soils (Direct emissions N2O)       9281
#                    Manure left on pasture (N content)                   9281
#                    Manure left on pasture that leaches (N content)      9281
#                    Emissions (N2O) (Manure applied)                     9281
#                    Enteric fermentation (Emissions CH4)                 9281
#                    Indirect emissions (N2O that leaches) (Manure a...   9281
#                    Indirect emissions (N2O that leaches) (Manure o...   9281
#                    Indirect emissions (N2O that volatilises) (Manu...   9281
#                    Indirect emissions (N2O that volatilises) (Manu...   9281
#                    Livestock total (Emissions CH4)                      9281
#                    Livestock total (Emissions N2O)                      9281
#                    Manure left on pasture that volatilises (N cont...   9281
#                    Manure applied to soils (Indirect emissions N2O)     9281
#                    Manure management (Direct emissions N2O)             9281
#                    Manure applied to soils (N content)                  9281
#                    Manure management (Indirect emissions N2O)           9281
#                    Manure management (Emissions CH4)                    9281
#                    Manure management (Emissions N2O)                    9281
#                    Manure left on pasture (Emissions N2O)               9281
#                    Manure left on pasture (Direct emissions N2O)        9281
#                    Manure applied to soils that volatilises (N con...   9281
#                    Manure applied to soils that leaches (N content)     9281
# Ducks              Stocks                                               7423
#                    Manure management (manure treated, N content)        7412
#                    Manure left on pasture (Direct emissions N2O)        7412
#                    Manure management (Indirect emissions N2O)           7412
#                    Manure management (Emissions N2O)                    7412
#                    Manure management (Emissions CH4)                    7412
#                    Manure management (Direct emissions N2O)             7412
#                    Manure left on pasture that volatilises (N cont...   7412
#                    Manure left on pasture that leaches (N content)      7412
#                    Manure left on pasture (N content)                   7412
#                    Manure left on pasture (Indirect emissions N2O)      7412
#                    Manure left on pasture (Emissions N2O)               7412
#                    Manure applied to soils (Direct emissions N2O)       7412
#                    Manure applied to soils that volatilises (N con...   7412
#                    Manure applied to soils that leaches (N content)     7412
#                    Manure applied to soils (N content)                  7412
#                    Manure applied to soils (Indirect emissions N2O)     7412
#                    Livestock total (Emissions N2O)                      7412
#                    Livestock total (Emissions CH4)                      7412
#                    Indirect emissions (N2O that volatilises) (Manu...   7412
#                    Indirect emissions (N2O that volatilises) (Manu...   7412
#                    Indirect emissions (N2O that leaches) (Manure o...   7412
#                    Indirect emissions (N2O that leaches) (Manure a...   7412
#                    Emissions (N2O) (Manure applied)                     7412
# Mules and hinnies  Stocks                                               6936
#                    Emissions (N2O) (Manure applied)                     6913
#                    Enteric fermentation (Emissions CH4)                 6913
#                    Manure management (Indirect emissions N2O)           6913
#                    Manure management (Emissions CH4)                    6913
#                    Manure management (Direct emissions N2O)             6913
#                    Manure left on pasture that volatilises (N cont...   6913
#                    Manure left on pasture that leaches (N content)      6913
#                    Manure left on pasture (N content)                   6913
#                    Manure left on pasture (Indirect emissions N2O)      6913
#                    Manure left on pasture (Emissions N2O)               6913
#                    Manure left on pasture (Direct emissions N2O)        6913
#                    Manure applied to soils that volatilises (N con...   6913
#                    Manure applied to soils that leaches (N content)     6913
#                    Manure applied to soils (N content)                  6913
#                    Manure applied to soils (Indirect emissions N2O)     6913
#                    Manure applied to soils (Direct emissions N2O)       6913
#                    Livestock total (Emissions N2O)                      6913
#                    Livestock total (Emissions CH4)                      6913
#                    Indirect emissions (N2O that volatilises) (Manu...   6913
#                    Indirect emissions (N2O that volatilises) (Manu...   6913
#                    Indirect emissions (N2O that leaches) (Manure o...   6913
#                    Indirect emissions (N2O that leaches) (Manure a...   6913
#                    Manure management (Emissions N2O)                    6913
#                    Manure management (manure treated, N content)        6913
# Turkeys            Indirect emissions (N2O that leaches) (Manure a...   6436
#                    Manure applied to soils that volatilises (N con...   6436
#                    Indirect emissions (N2O that leaches) (Manure o...   6436
#                    Indirect emissions (N2O that volatilises) (Manu...   6436
#                    Indirect emissions (N2O that volatilises) (Manu...   6436
#                    Livestock total (Emissions CH4)                      6436
#                    Livestock total (Emissions N2O)                      6436
#                    Manure applied to soils (Direct emissions N2O)       6436
#                    Manure applied to soils (Indirect emissions N2O)     6436
#                    Manure applied to soils (N content)                  6436
#                    Manure applied to soils that leaches (N content)     6436
#                    Manure left on pasture (Direct emissions N2O)        6436
#                    Manure management (manure treated, N content)        6436
#                    Manure left on pasture (Emissions N2O)               6436
#                    Manure left on pasture (Indirect emissions N2O)      6436
#                    Manure left on pasture (N content)                   6436
#                    Manure left on pasture that leaches (N content)      6436
#                    Manure left on pasture that volatilises (N cont...   6436
#                    Manure management (Direct emissions N2O)             6436
#                    Manure management (Emissions CH4)                    6436
#                    Manure management (Emissions N2O)                    6436
#                    Manure management (Indirect emissions N2O)           6436
#                    Emissions (N2O) (Manure applied)                     6436
#                    Stocks                                               6436
# Buffalo            Stocks                                               4658
#                    Enteric fermentation (Emissions CH4)                 4610
#                    Livestock total (Emissions CH4)                      4610
#                    Manure left on pasture (N content)                   4540
#                    Manure management (Direct emissions N2O)             4538
#                    Manure management (manure treated, N content)        4538
# Camels             Stocks                                               4249
# Buffalo            Manure management (Emissions CH4)                    4215
#                    Livestock total (Emissions N2O)                      4214
#                    Manure management (Emissions N2O)                    4214
#                    Manure applied to soils (N content)                  4203
#                    Manure applied to soils that volatilises (N con...   4203
#                    Manure left on pasture (Direct emissions N2O)        4203
#                    Manure left on pasture (Emissions N2O)               4203
#                    Manure applied to soils that leaches (N content)     4203
#                    Manure applied to soils (Direct emissions N2O)       4203
#                    Manure left on pasture (Indirect emissions N2O)      4203
#                    Manure left on pasture that leaches (N content)      4203
#                    Manure left on pasture that volatilises (N cont...   4203
#                    Manure management (Indirect emissions N2O)           4203
#                    Manure applied to soils (Indirect emissions N2O)     4203
#                    Indirect emissions (N2O that leaches) (Manure a...   4203
#                    Indirect emissions (N2O that volatilises) (Manu...   4203
#                    Indirect emissions (N2O that volatilises) (Manu...   4203
#                    Indirect emissions (N2O that leaches) (Manure o...   4203
#                    Emissions (N2O) (Manure applied)                     4203
# Camels             Livestock total (Emissions CH4)                      4180
#                    Enteric fermentation (Emissions CH4)                 4180
# Camels and Llamas  Manure management (Direct emissions N2O)             4167
#                    Manure management (Emissions CH4)                    4167
#                    Manure management (Emissions N2O)                    4167
#                    Manure management (Indirect emissions N2O)           4167
#                    Manure management (manure treated, N content)        4167
#                    Stocks                                               4167
#                    Manure left on pasture that volatilises (N cont...   4167
#                    Manure applied to soils that leaches (N content)     4167
#                    Indirect emissions (N2O that leaches) (Manure a...   4167
#                    Manure left on pasture (N content)                   4167
#                    Manure left on pasture (Indirect emissions N2O)      4167
#                    Manure left on pasture (Emissions N2O)               4167
#                    Manure left on pasture (Direct emissions N2O)        4167
#                    Manure applied to soils that volatilises (N con...   4167
#                    Manure applied to soils (N content)                  4167
#                    Manure applied to soils (Indirect emissions N2O)     4167
#                    Manure applied to soils (Direct emissions N2O)       4167
#                    Livestock total (Emissions N2O)                      4167
#                    Livestock total (Emissions CH4)                      4167
#                    Indirect emissions (N2O that volatilises) (Manu...   4167
#                    Indirect emissions (N2O that volatilises) (Manu...   4167
#                    Indirect emissions (N2O that leaches) (Manure o...   4167
#                    Manure left on pasture that leaches (N content)      4167
# Camels             Manure left on pasture (N content)                   4122
#                    Manure management (Direct emissions N2O)             4060
#                    Manure management (manure treated, N content)        4060
#                    Manure management (Emissions CH4)                    3943
#                    Livestock total (Emissions N2O)                      3916
#                    Manure management (Emissions N2O)                    3916
#                    Indirect emissions (N2O that volatilises) (Manu...   3915
#                    Manure left on pasture (Emissions N2O)               3915
#                    Emissions (N2O) (Manure applied)                     3915
#                    Indirect emissions (N2O that leaches) (Manure a...   3915
#                    Indirect emissions (N2O that leaches) (Manure o...   3915
#                    Manure left on pasture (Direct emissions N2O)        3915
#                    Indirect emissions (N2O that volatilises) (Manu...   3915
#                    Manure management (Indirect emissions N2O)           3915
#                    Manure applied to soils (Direct emissions N2O)       3915
#                    Manure left on pasture that leaches (N content)      3915
#                    Manure left on pasture that volatilises (N cont...   3915
#                    Manure left on pasture (Indirect emissions N2O)      3915
#                    Manure applied to soils that volatilises (N con...   3915
#                    Manure applied to soils that leaches (N content)     3915
#                    Manure applied to soils (N content)                  3915
#                    Manure applied to soils (Indirect emissions N2O)     3915
# Llamas             Stocks                                                504
#                    Manure management (manure treated, N content)         504
#                    Manure left on pasture (Direct emissions N2O)         504
#                    Manure management (Indirect emissions N2O)            504
#                    Manure management (Emissions N2O)                     504
#                    Manure management (Emissions CH4)                     504
#                    Manure management (Direct emissions N2O)              504
#                    Manure left on pasture that volatilises (N cont...    504
#                    Manure left on pasture that leaches (N content)       504
#                    Manure left on pasture (N content)                    504
#                    Manure left on pasture (Indirect emissions N2O)       504
#                    Manure left on pasture (Emissions N2O)                504
#                    Manure applied to soils (Direct emissions N2O)        504
#                    Manure applied to soils that volatilises (N con...    504
#                    Manure applied to soils that leaches (N content)      504
#                    Manure applied to soils (N content)                   504
#                    Manure applied to soils (Indirect emissions N2O)      504
#                    Livestock total (Emissions N2O)                       504
#                    Livestock total (Emissions CH4)                       504
#                    Indirect emissions (N2O that volatilises) (Manu...    504
#                    Indirect emissions (N2O that volatilises) (Manu...    504
#                    Indirect emissions (N2O that leaches) (Manure o...    504
#                    Enteric fermentation (Emissions CH4)                  504
#                    Emissions (N2O) (Manure applied)                      504
#                    Indirect emissions (N2O that leaches) (Manure a...    504

# %% [markdown]
# # Convertir tablas mediante "group by" y SUMANDO el valor para cada combinacion

# %% [markdown]
# ### Seleccionando elementos e items especificos
#
# Por ejemplo para esta tabla solo:
#
# Items: Enteric Fermentation, Agrifood systems
#
# Element: Emissions (CO2eq) (AR5)

# %%
# Define selected Elements and selected Items
selected_Elements = ['Livestock total (Emissions CH4)']
selected_Items = ['Chickens', 'Camels']

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(selected_Elements)) & (df['Item'].isin(selected_Items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %% [markdown]
# **El codigo genera una columna nueva para cada combinacion de item y element**

# %%
pd.reset_option('display.max_rows')
pivot_df
# Out:
#        Area Code     Area  Year  Camels_Livestock total (Emissions CH4)  \
# 0              1  Armenia  1992                                     NaN
# 1              1  Armenia  1993                                     NaN
# 2              1  Armenia  1994                                     NaN
# 3              1  Armenia  1995                                     NaN
# 4              1  Armenia  1996                                     NaN
# ...          ...      ...   ...                                     ...
# 14139       5873     OECD  2019                                  0.3455
# 14140       5873     OECD  2020                                  0.3294
# 14141       5873     OECD  2021                                  0.3260
# 14142       5873     OECD  2030                                  0.2962
# 14143       5873     OECD  2050                                  0.2962
#
#        Chickens_Livestock total (Emissions CH4)
# 0                                        0.0893
# 1                                        0.0266
# 2                                        0.0269
# 3                                        0.0271
# 4                                        0.0272
# ...                                         ...
# 14139                                  237.0858
# 14140                                  236.4638
# 14141                                  235.3482
# 14142                                  236.9513
# 14143                                  243.3289
#
# [14144 rows x 5 columns]

# %% [markdown]
# **Guardar tabla si queremos esta opcion**
#
# Sino continuar

# %%
#new_file_name = file_name.split('.')[0]
#pivot_df.to_csv(rf'.\data\FAOSTAT\clean_data\country_tables\{new_file_name}_clean_groupby_country_year.csv')

# %% [markdown]
# ### Seleccionando TODOS las combinaciones de item y element que hay

# %%
# Extract all unique items and elements
unique_items = df['Item'].unique()
unique_elements = df['Element'].unique()

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(unique_elements)) & (df['Item'].isin(unique_items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %%
pivot_df
# Out:
#        Area Code     Area  Year  All Animals_Emissions (N2O) (Manure applied)  \
# 0              1  Armenia  1992                                        0.1258
# 1              1  Armenia  1993                                        0.0642
# 2              1  Armenia  1994                                        0.0637
# 3              1  Armenia  1995                                        0.0630
# 4              1  Armenia  1996                                        0.0624
# ...          ...      ...   ...                                           ...
# 14212       5873     OECD  2019                                      190.4058
# 14213       5873     OECD  2020                                      190.1513
# 14214       5873     OECD  2021                                      188.7676
# 14215       5873     OECD  2030                                      195.7446
# 14216       5873     OECD  2050                                      195.4226
#
#        All Animals_Enteric fermentation (Emissions CH4)  \
# 0                                               26.8300
# 1                                               23.9849
# 2                                               23.6415
# 3                                               23.3360
# 4                                               23.3053
# ...                                                 ...
# 14212                                        20860.9811
# 14213                                        20687.2388
# 14214                                        20738.8354
# 14215                                        22540.5992
# 14216                                        22515.7130
#
#        All Animals_Indirect emissions (N2O that leaches) (Manure applied)  \
# 0                                                 0.0199
# 1                                                 0.0101
# 2                                                 0.0101
# 3                                                 0.0099
# 4                                                 0.0098
# ...                                                  ...
# 14212                                            30.0641
# 14213                                            30.0239
# 14214                                            29.8054
# 14215                                            30.9070
# 14216                                            30.8562
#
#        All Animals_Indirect emissions (N2O that leaches) (Manure on pasture)  \
# 0                                                 0.1595
# 1                                                 0.1371
# 2                                                 0.1330
# 3                                                 0.1293
# 4                                                 0.1287
# ...                                                  ...
# 14212                                            53.0452
# 14213                                            52.6270
# 14214                                            53.1869
# 14215                                            61.0169
# 14216                                            62.3299
#
#        All Animals_Indirect emissions (N2O that volatilises) (Manure applied)  \
# 0                                                 0.0177
# 1                                                 0.0090
# 2                                                 0.0089
# 3                                                 0.0088
# 4                                                 0.0088
# ...                                                  ...
# 14212                                            26.7236
# 14213                                            26.6879
# 14214                                            26.4937
# 14215                                            27.4729
# 14216                                            27.4277
#
#        All Animals_Indirect emissions (N2O that volatilises) (Manure on pasture)  \
# 0                                                 0.1417
# 1                                                 0.1219
# 2                                                 0.1183
# 3                                                 0.1150
# 4                                                 0.1144
# ...                                                  ...
# 14212                                            47.1513
# 14213                                            46.7796
# 14214                                            47.2772
# 14215                                            54.2372
# 14216                                            55.4044
#
#        All Animals_Livestock total (Emissions CH4)  ...  \
# 0                                          28.0780  ...
# 1                                          24.9554  ...
# 2                                          24.6155  ...
# 3                                          24.3106  ...
# 4                                          24.2789  ...
# ...                                            ...  ...
# 14212                                   24968.3867  ...
# 14213                                   24786.3914  ...
# 14214                                   24789.9359  ...
# 14215                                   26619.6309  ...
# 14216                                   26570.6256  ...
#
#        Turkeys_Manure left on pasture (Indirect emissions N2O)  \
# 0                                                 0.0035
# 1                                                 0.0026
# 2                                                 0.0026
# 3                                                 0.0017
# 4                                                 0.0017
# ...                                                  ...
# 14212                                             0.2596
# 14213                                             0.2609
# 14214                                             0.2593
# 14215                                             0.3457
# 14216                                             0.3953
#
#        Turkeys_Manure left on pasture (N content)  \
# 0                                    5.216171e+05
# 1                                    3.912128e+05
# 2                                    3.912128e+05
# 3                                    2.608086e+05
# 4                                    2.608086e+05
# ...                                           ...
# 14212                                3.887458e+07
# 14213                                3.906094e+07
# 14214                                3.883273e+07
# 14215                                5.176058e+07
# 14216                                5.919659e+07
#
#        Turkeys_Manure left on pasture that leaches (N content)  \
# 0                                           1.564851e+05
# 1                                           1.173639e+05
# 2                                           1.173639e+05
# 3                                           7.824257e+04
# 4                                           7.824257e+04
# ...                                                  ...
# 14212                                       1.166237e+07
# 14213                                       1.171828e+07
# 14214                                       1.164982e+07
# 14215                                       1.552817e+07
# 14216                                       1.775898e+07
#
#        Turkeys_Manure left on pasture that volatilises (N content)  \
# 0                                           1.043234e+05
# 1                                           7.824257e+04
# 2                                           7.824257e+04
# 3                                           5.216171e+04
# 4                                           5.216171e+04
# ...                                                  ...
# 14212                                       7.774916e+06
# 14213                                       7.812189e+06
# 14214                                       7.766547e+06
# 14215                                       1.035212e+07
# 14216                                       1.183932e+07
#
#        Turkeys_Manure management (Direct emissions N2O)  \
# 0                                                0.0017
# 1                                                0.0013
# 2                                                0.0013
# 3                                                0.0008
# 4                                                0.0008
# ...                                                 ...
# 14212                                            2.7055
# 14213                                            2.6847
# 14214                                            2.6335
# 14215                                            3.2249
# 14216                                            3.3906
#
#        Turkeys_Manure management (Emissions CH4)  \
# 0                                         0.0040
# 1                                         0.0030
# 2                                         0.0030
# 3                                         0.0020
# 4                                         0.0020
# ...                                          ...
# 14212                                    15.9601
# 14213                                    15.8414
# 14214                                    15.5198
# 14215                                    18.8967
# 14216                                    19.7581
#
#        Turkeys_Manure management (Emissions N2O)  \
# 0                                         0.0017
# 1                                         0.0013
# 2                                         0.0013
# 3                                         0.0008
# 4                                         0.0008
# ...                                          ...
# 14212                                     2.7567
# 14213                                     2.7353
# 14214                                     2.6824
# 14215                                     3.2933
# 14216                                     3.4678
#
#        Turkeys_Manure management (Indirect emissions N2O)  \
# 0                                                 0.0000
# 1                                                 0.0000
# 2                                                 0.0000
# 3                                                 0.0000
# 4                                                 0.0000
# ...                                                  ...
# 14212                                             0.0512
# 14213                                             0.0506
# 14214                                             0.0489
# 14215                                             0.0684
# 14216                                             0.0773
#
#        Turkeys_Manure management (manure treated, N content)  Turkeys_Stocks
# 0                                           2.130549e+05            400000.0
# 1                                           1.597912e+05            300000.0
# 2                                           1.597912e+05            300000.0
# 3                                           1.065274e+05            200000.0
# 4                                           1.065274e+05            200000.0
# ...                                                  ...                 ...
# 14212                                       3.498877e+08         211665832.0
# 14213                                       3.471659e+08         210285394.0
# 14214                                       3.403803e+08         206466645.0
# 14215                                       4.184029e+08         255985609.0
# 14216                                       4.411571e+08         272422989.0
#
# [14217 rows x 588 columns]

# %% [markdown]
# # Alternativa para este caso en particular:
#
# La tabla final tendria 252 columnas (252 combinaciones de item y element). No nos interesa tantos datos de cada tabla.
#
# Pueden seleccionar todos los items pero solo 1 Element--->

# %%
# Extract all unique items and elements
unique_items = df['Item'].unique()
unique_elements = ['Emissions (CO2eq) (AR5)']

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(unique_elements)) & (df['Item'].isin(unique_items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %%
pivot_df
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Year]
# Index: []

# %% [markdown]
# # A partir de aqui se pueden eliminar o retener las columnas que sean utiles

# %%
#new_file_name = file_name.split('.')[0]
#pivot_df.to_csv(rf'.\data\FAOSTAT\clean_data\country_tables\{new_file_name}_clean_groupby_country_year.csv')
