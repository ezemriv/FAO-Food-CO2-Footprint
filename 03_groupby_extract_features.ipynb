# %% [markdown]
# # Script para extraer datos utiles de cada tabla desde el formato zip directamente

# %%
import pandas as pd
import numpy as np
import zipfile
import io

#supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
zip_path = r'.\data\FAOSTAT\all_raw\Emissions_Totals_E_All_Data_(Normalized).zip'

# %% [markdown]
# ### Abrir el CSV dentro del zip file que incluye el patron "All_Data_" y guardarlo en un dataframe

# %%
# Initialize an empty DataFrame
df = pd.DataFrame()

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List all files in the zip archive
    all_files = zip_ref.namelist()
    print("Files in the zip archive:", all_files)
    
    # Iterate through the file names in the zip archive
    for file_name in all_files:
        # Check if the file name contains the pattern "All_Data_"
        if "All_Data_" in file_name and file_name.endswith(".csv"):
            print(f"Found matching file: {file_name}")
            # Read the CSV file into a DataFrame
            with zip_ref.open(file_name) as file:
                temp_df = pd.read_csv(file, encoding = "ISO-8859-1")
                # Concatenate the data from this CSV to the main DataFrame
                df = pd.concat([df, temp_df], ignore_index=True)
# Out:
# Files in the zip archive: ['Emissions_Totals_E_All_Data_(Normalized).csv', 'Emissions_Totals_E_AreaCodes.csv', 'Emissions_Totals_E_Flags.csv']
# Found matching file: Emissions_Totals_E_All_Data_(Normalized).csv

# %% [markdown]
# ### Determinar si es una tabla de PAISES, COMIDAS, MIXTA o OTRAS
#
# (mirando bien creo que no hay tablas solo de comidas)

# %%
condition_paises = all(col in df.columns for col in ['Area Code', 'Year'])
condition_comida = df['Item'].isin(['Meat of chickens; fresh or chilled', 'Tapioca of cassava', 'Wheat', 'Barley', 'Cattle']).any()

if condition_paises and not condition_comida:
    print("La tabla parece ser SOLO de PAISES")
elif condition_comida and condition_paises:
    print("La tabla parece ser de COMIDAS (comidas, cultivos o animales) Y PAISES")
else:
    print("Ni idea que es esta tabla")
# Out:
# La tabla parece ser SOLO de PAISES

# %%
df.head()
# Out:
#    Area Code Area Code (M49)         Area  Item Code           Item  \
# 0          2            '004  Afghanistan       5064  Crop Residues
# 1          2            '004  Afghanistan       5064  Crop Residues
# 2          2            '004  Afghanistan       5064  Crop Residues
# 3          2            '004  Afghanistan       5064  Crop Residues
# 4          2            '004  Afghanistan       5064  Crop Residues
#
#    Element Code                 Element  Year Code  Year  Source Code  \
# 0          7234  Direct emissions (N2O)       1961  1961         3050
# 1          7234  Direct emissions (N2O)       1962  1962         3050
# 2          7234  Direct emissions (N2O)       1963  1963         3050
# 3          7234  Direct emissions (N2O)       1964  1964         3050
# 4          7234  Direct emissions (N2O)       1965  1965         3050
#
#        Source Unit   Value Flag  Note
# 0  FAO TIER 1   kt  0.8762    E   NaN
# 1  FAO TIER 1   kt  0.8829    E   NaN
# 2  FAO TIER 1   kt  0.8236    E   NaN
# 3  FAO TIER 1   kt  0.8882    E   NaN
# 4  FAO TIER 1   kt  0.8978    E   NaN

# %% [markdown]
# Ver las diferentes combinaciones de item y element que hay

# %%
pd.set_option('display.max_rows', None)
df.groupby('Item')['Element'].value_counts().to_frame().sort_values(by = 'count', ascending=False)
# Out:
#                                                                       count
# Item                            Element
# IPCC Agriculture                Emissions (CO2eq) (AR5)               17095
#                                 Emissions (N2O)                       17057
#                                 Emissions (CO2eq) from N2O (AR5)      17057
#                                 Emissions (CO2eq) from CH4 (AR5)      17019
#                                 Emissions (CH4)                       17019
# Agricultural Soils              Emissions (N2O)                       16808
#                                 Emissions (CO2eq) from N2O (AR5)      16808
#                                 Emissions (CO2eq) (AR5)               16808
# Manure Management               Emissions (CO2eq) (AR5)               16286
#                                 Emissions (CO2eq) from CH4 (AR5)      16247
#                                 Emissions (CH4)                       16247
# Enteric Fermentation            Emissions (CO2eq) from CH4 (AR5)      16245
#                                 Emissions (CO2eq) (AR5)               16245
#                                 Emissions (CH4)                       16245
# Manure Management               Emissions (CO2eq) from N2O (AR5)      16136
#                                 Emissions (N2O)                       16136
# Manure applied to Soils         Emissions (N2O)                       15557
#                                 Emissions (CO2eq) from N2O (AR5)      15557
#                                 Direct emissions (N2O)                15557
#                                 Emissions (CO2eq) (AR5)               15557
# Agricultural Soils              Direct emissions (N2O)                15538
#                                 Indirect emissions (N2O)              15483
# Agrifood systems                Emissions (CO2eq) (AR5)               14994
#                                 Emissions (CO2eq) from N2O (AR5)      14994
#                                 Emissions (N2O)                       14994
#                                 Emissions (CH4)                       14965
#                                 Emissions (CO2eq) from CH4 (AR5)      14965
# Crop Residues                   Emissions (CO2eq) (AR5)               14932
#                                 Emissions (N2O)                       14932
#                                 Emissions (CO2eq) from N2O (AR5)      14932
# All sectors without LULUCF      Emissions (N2O)                       14838
#                                 Emissions (CO2eq) from N2O (AR5)      14838
#                                 Emissions (CO2eq) (AR5)               14838
# All sectors with LULUCF         Emissions (CO2eq) from N2O (AR5)      14838
#                                 Emissions (N2O)                       14838
#                                 Emissions (CO2eq) (AR5)               14838
#                                 Emissions (CO2eq) from CH4 (AR5)      14804
# All sectors without LULUCF      Emissions (CH4)                       14804
# All sectors with LULUCF         Emissions (CH4)                       14804
# All sectors without LULUCF      Emissions (CO2eq) from CH4 (AR5)      14804
# Crop Residues                   Direct emissions (N2O)                14583
# Burning - Crop residues         Emissions (CO2eq) (AR5)               14543
#                                 Emissions (CH4)                       14538
#                                 Emissions (CO2eq) from CH4 (AR5)      14538
#                                 Emissions (N2O)                       14469
#                                 Emissions (CO2eq) from N2O (AR5)      14469
# Manure left on Pasture          Direct emissions (N2O)                14313
#                                 Emissions (CO2eq) (AR5)               14313
#                                 Emissions (N2O)                       14313
#                                 Emissions (CO2eq) from N2O (AR5)      14313
# Synthetic Fertilizers           Direct emissions (N2O)                14289
#                                 Emissions (CO2eq) (AR5)               14289
#                                 Emissions (CO2eq) from N2O (AR5)      14289
#                                 Emissions (N2O)                       14289
# Emissions from livestock        Direct emissions (N2O)                14207
# Manure Management               Indirect emissions (N2O)              14207
# Emissions from livestock        Indirect emissions (N2O)              14207
# Manure Management               Direct emissions (N2O)                14207
# Emissions from livestock        Emissions (N2O)                       14207
#                                 Emissions (CO2eq) from N2O (AR5)      14207
#                                 Emissions (CO2eq) (AR5)               14207
#                                 Emissions (CH4)                       14207
#                                 Emissions (CO2eq) from CH4 (AR5)      14207
# Manure applied to Soils         Indirect emissions (N2O)              14207
# Manure left on Pasture          Indirect emissions (N2O)              14207
# All sectors without LULUCF      Direct emissions (N2O)                14010
# IPCC Agriculture                Direct emissions (N2O)                14010
# All sectors with LULUCF         Indirect emissions (N2O)              14010
#                                 Direct emissions (N2O)                14010
# Agrifood systems                Indirect emissions (N2O)              14010
#                                 Direct emissions (N2O)                14010
# IPCC Agriculture                Indirect emissions (N2O)              14010
# All sectors without LULUCF      Indirect emissions (N2O)              14010
# Emissions from crops            Emissions (CO2eq) (AR5)               13529
#                                 Emissions (N2O)                       13529
#                                 Emissions (CO2eq) from N2O (AR5)      13529
#                                 Emissions (CO2eq) from CH4 (AR5)      13349
#                                 Emissions (CH4)                       13349
# Crop Residues                   Indirect emissions (N2O)              13180
# Emissions from crops            Indirect emissions (N2O)              13180
#                                 Direct emissions (N2O)                13180
# Synthetic Fertilizers           Indirect emissions (N2O)              12850
# Agrifood systems                Emissions (CO2)                       12122
# LULUCF                          Emissions (CO2eq) (AR5)               10670
#                                 Emissions (CO2)                       10670
#                                 Emissions (N2O)                       10227
# Rice Cultivation                Emissions (CO2eq) from CH4 (AR5)      10223
#                                 Emissions (CO2eq) (AR5)               10223
#                                 Emissions (CH4)                       10223
# LULUCF                          Emissions (CH4)                       10146
# Drained organic soils           Emissions (CO2eq) (AR5)                9730
# Drained organic soils (N2O)     Emissions (N2O)                        9706
#                                 Emissions (CO2eq) from N2O (AR5)       9706
#                                 Emissions (CO2eq) (AR5)                9706
# Forestland                      Emissions (CO2)                        9582
#                                 Emissions (CO2eq) (AR5)                9582
# Net Forest conversion           Emissions (CO2eq) (AR5)                9495
#                                 Emissions (CO2)                        9495
# Savanna fires                   Emissions (N2O)                        9281
#                                 Emissions (CO2eq) (AR5)                9281
#                                 Emissions (CO2eq) from N2O (AR5)       9281
#                                 Emissions (CH4)                        9281
#                                 Emissions (CO2eq) from CH4 (AR5)       9281
# Drained organic soils (CO2)     Emissions (CO2)                        8852
#                                 Emissions (CO2eq) (AR5)                8852
# Forest fires                    Emissions (N2O)                        8626
#                                 Emissions (CO2eq) from N2O (AR5)       8626
#                                 Emissions (CO2eq) from CH4 (AR5)       8626
#                                 Emissions (CO2eq) (AR5)                8626
#                                 Emissions (CH4)                        8626
# AFOLU                           Emissions (CO2)                        8598
# Agrifood systems                Emissions (CO2eq) from F-gases (AR5)   8598
# Farm gate                       Emissions (CO2eq) (AR5)                8598
#                                 Emissions (CO2eq) from N2O (AR5)       8598
#                                 Emissions (N2O)                        8598
# Emissions on agricultural land  Emissions (CO2eq) (AR5)                8598
# AFOLU                           Emissions (CO2eq) (AR5)                8598
# Emissions on agricultural land  Emissions (CO2)                        8598
# All sectors with LULUCF         Emissions (CO2)                        8598
# Pre- and Post- Production       Emissions (CO2eq) from F-gases (AR5)   8598
# Emissions on agricultural land  Emissions (N2O)                        8598
# Pre- and Post- Production       Emissions (CO2eq) (AR5)                8598
# AFOLU                           Emissions (N2O)                        8598
#                                 Emissions (CO2eq) from N2O (AR5)       8598
# Emissions on agricultural land  Emissions (CO2eq) from N2O (AR5)       8598
# Food Transport                  Emissions (CO2eq) (AR5)                8596
#                                 Emissions (CO2eq) from F-gases (AR5)   8596
# AFOLU                           Emissions (CO2eq) from CH4 (AR5)       8566
# Pre- and Post- Production       Emissions (N2O)                        8566
# AFOLU                           Emissions (CH4)                        8566
# Emissions on agricultural land  Emissions (CO2eq) from CH4 (AR5)       8566
#                                 Emissions (CH4)                        8566
# Pre- and Post- Production       Emissions (CO2eq) from CH4 (AR5)       8566
# Land Use change                 Emissions (CO2)                        8566
#                                 Emissions (CO2eq) (AR5)                8566
# Pre- and Post- Production       Emissions (CH4)                        8566
#                                 Emissions (CO2eq) from N2O (AR5)       8566
# Farm gate                       Emissions (CO2eq) from CH4 (AR5)       8566
#                                 Emissions (CO2)                        8566
#                                 Emissions (CH4)                        8566
# LULUCF                          Emissions (CO2eq) from N2O (AR5)       8502
# Pre- and Post- Production       Emissions (CO2)                        8502
# LULUCF                          Emissions (CO2eq) from CH4 (AR5)       8502
# Fires in organic soils          Emissions (CO2eq) (AR5)                8498
#                                 Emissions (CO2)                        8498
# Land Use change                 Emissions (N2O)                        8438
#                                 Emissions (CO2eq) from N2O (AR5)       8438
#                                 Emissions (CO2eq) from CH4 (AR5)       8438
#                                 Emissions (CH4)                        8438
# Fires in humid tropical forests Emissions (CO2eq) from N2O (AR5)       8438
#                                 Emissions (CH4)                        8438
#                                 Emissions (CO2eq) (AR5)                8438
#                                 Emissions (CO2eq) from CH4 (AR5)       8438
#                                 Emissions (N2O)                        8438
# Fires in organic soils          Emissions (CH4)                        8438
#                                 Emissions (CO2eq) from CH4 (AR5)       8438
# Agrifood Systems Waste Disposal Emissions (N2O)                        8406
#                                 Emissions (CO2eq) from N2O (AR5)       8406
#                                 Emissions (CO2eq) from CH4 (AR5)       8406
#                                 Emissions (CO2eq) (AR5)                8406
#                                 Emissions (CH4)                        8406
# On-farm energy use              Emissions (CO2)                        8182
#                                 Emissions (CH4)                        8182
#                                 Emissions (CO2eq) (AR5)                8182
#                                 Emissions (CO2eq) from N2O (AR5)       8182
#                                 Emissions (N2O)                        8182
#                                 Emissions (CO2eq) from CH4 (AR5)       8182
# Food Household Consumption      Emissions (CO2eq) (AR5)                8075
# Food Transport                  Emissions (CO2eq) from CH4 (AR5)       8073
#                                 Emissions (CO2)                        8073
#                                 Emissions (CH4)                        8073
#                                 Emissions (N2O)                        8073
#                                 Emissions (CO2eq) from N2O (AR5)       8073
# Food Retail                     Emissions (CO2eq) (AR5)                7954
# Food Household Consumption      Emissions (CH4)                        7883
#                                 Emissions (CO2)                        7883
#                                 Emissions (N2O)                        7883
#                                 Emissions (CO2eq) from N2O (AR5)       7883
#                                 Emissions (CO2eq) from CH4 (AR5)       7883
# Pesticides Manufacturing        Emissions (CH4)                        7855
#                                 Emissions (CO2)                        7855
#                                 Emissions (CO2eq) (AR5)                7855
#                                 Emissions (N2O)                        7855
# Agrifood Systems Waste Disposal Emissions (CO2)                        7844
# Farm gate                       Indirect emissions (N2O)               7770
# AFOLU                           Direct emissions (N2O)                 7770
#                                 Indirect emissions (N2O)               7770
# Emissions on agricultural land  Indirect emissions (N2O)               7770
#                                 Direct emissions (N2O)                 7770
# Farm gate                       Direct emissions (N2O)                 7770
# Waste                           Emissions (CH4)                        7703
#                                 Emissions (CO2eq) from CH4 (AR5)       7703
#                                 Emissions (CO2eq) (AR5)                7703
# IPPU                            Emissions (CO2)                        7671
# Energy                          Emissions (CO2eq) (AR5)                7671
#                                 Emissions (CO2)                        7671
# IPPU                            Emissions (CO2eq) (AR5)                7671
# All sectors without LULUCF      Emissions (CO2)                        7671
# Energy                          Emissions (N2O)                        7608
#                                 Emissions (CO2eq) from N2O (AR5)       7608
#                                 Emissions (CO2eq) from CH4 (AR5)       7608
#                                 Emissions (CH4)                        7608
# IPPU                            Emissions (N2O)                        7544
# Other                           Emissions (CO2eq) (AR5)                7544
# IPPU                            Emissions (CO2eq) from N2O (AR5)       7544
# Other                           Emissions (N2O)                        7544
#                                 Emissions (CO2eq) from N2O (AR5)       7544
# Food Retail                     Emissions (N2O)                        7492
#                                 Emissions (CO2eq) from N2O (AR5)       7492
#                                 Emissions (CO2eq) from CH4 (AR5)       7492
#                                 Emissions (CO2)                        7492
#                                 Emissions (CH4)                        7492
#                                 Emissions (CO2eq) from F-gases (AR5)   7472
# Waste                           Emissions (N2O)                        7416
#                                 Emissions (CO2eq) from N2O (AR5)       7416
# Pesticides Manufacturing        Emissions (CO2eq) from N2O (AR5)       6641
#                                 Emissions (CO2eq) from CH4 (AR5)       6641
# IPPU                            Emissions (CO2eq) from F-gases (AR5)   6249
# All sectors without LULUCF      Emissions (CO2eq) from F-gases (AR5)   6249
# All sectors with LULUCF         Emissions (CO2eq) from F-gases (AR5)   6249
# Food Packaging                  Emissions (CO2)                        5943
#                                 Emissions (N2O)                        5943
#                                 Emissions (CH4)                        5943
#                                 Emissions (CO2eq) (AR5)                5943
#                                 Emissions (CO2eq) from CH4 (AR5)       5943
#                                 Emissions (CO2eq) from N2O (AR5)       5943
# Food Processing                 Emissions (CO2eq) (AR5)                5885
#                                 Emissions (CO2)                        5861
#                                 Emissions (CH4)                        5861
#                                 Emissions (N2O)                        5861
#                                 Emissions (CO2eq) from N2O (AR5)       5861
#                                 Emissions (CO2eq) from CH4 (AR5)       5861
# Waste                           Emissions (CO2)                        5444
# IPPU                            Emissions (CH4)                        4833
#                                 Emissions (CO2eq) from CH4 (AR5)       4833
# Food Household Consumption      Emissions (CO2eq) from F-gases (AR5)   4702
# Fertilizers Manufacturing       Emissions (CO2eq) (AR5)                3614
#                                 Emissions (CO2)                        3614
# Other                           Emissions (CO2eq) from CH4 (AR5)       2615
#                                 Emissions (CH4)                        2615
#                                 Emissions (CO2)                        2581
# Fertilizers Manufacturing       Emissions (N2O)                        2534
#                                 Emissions (CO2eq) from N2O (AR5)       2534
# Food Processing                 Emissions (CO2eq) from F-gases (AR5)   1974
# IPCC Agriculture                Emissions (CO2)                        1349
# Savanna fires                   Emissions (CO2)                         278
# Forest fires                    Emissions (CO2)                          93
# Agricultural Soils              Emissions (CO2eq) from CH4 (AR5)          9
#                                 Emissions (CH4)                           9

# %% [markdown]
# # Convertir tablas mediante "group by" y SUMANDO el valor para cada combinacion

# %% [markdown]
# ### Seleccionando elementos e items especificos
#
# Por ejemplo para esta tabla solo:
#
# Items: Enteric Fermentation, Agrifood systems
#
# Element: Emissions (CO2eq) (AR5)

# %%
# Define selected Elements and selected Items
selected_Elements = ['Emissions (CO2eq) (AR5)']
selected_Items = ['Enteric Fermentation', 'Agrifood systems']

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(selected_Elements)) & (df['Item'].isin(selected_Items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %% [markdown]
# **El codigo genera una columna nueva para cada combinacion de item y element**

# %%
pd.reset_option('display.max_rows')
pivot_df
# Out:
#        Area Code     Area  Year  Agrifood systems_Emissions (CO2eq) (AR5)  \
# 0              1  Armenia  1992                              2.997345e+03
# 1              1  Armenia  1993                              1.841726e+03
# 2              1  Armenia  1994                              1.848546e+03
# 3              1  Armenia  1995                              1.959937e+03
# 4              1  Armenia  1996                              1.834244e+03
# ...          ...      ...   ...                                       ...
# 15463       5873     OECD  2019                              3.512659e+06
# 15464       5873     OECD  2020                              3.438269e+06
# 15465       5873     OECD  2021                              3.530872e+06
# 15466       5873     OECD  2030                                       NaN
# 15467       5873     OECD  2050                                       NaN
#
#        Enteric Fermentation_Emissions (CO2eq) (AR5)
# 0                                          751.2400
# 1                                          671.5772
# 2                                          661.9620
# 3                                          653.4080
# 4                                          652.5484
# ...                                             ...
# 15463                                   584107.4736
# 15464                                   579242.6892
# 15465                                   580687.3884
# 15466                                   631136.7748
# 15467                                   630439.9696
#
# [15468 rows x 5 columns]

# %% [markdown]
# **Guardar tabla si queremos esta opcion**
#
# Sino continuar

# %%
#new_file_name = file_name.split('.')[0]
#pivot_df.to_csv(rf'.\data\FAOSTAT\clean_data\country_tables\{new_file_name}_clean_groupby_country_year.csv')

# %% [markdown]
# ### Seleccionando TODOS las combinaciones de item y element que hay

# %%
# Extract all unique items and elements
unique_items = df['Item'].unique()
unique_elements = df['Element'].unique()

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(unique_elements)) & (df['Item'].isin(unique_items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %%
pivot_df
# Out:
#        Area Code     Area  Year  AFOLU_Direct emissions (N2O)  \
# 0              1  Armenia  1992                        1.7228
# 1              1  Armenia  1993                        1.4569
# 2              1  Armenia  1994                        1.3019
# 3              1  Armenia  1995                        1.2884
# 4              1  Armenia  1996                        1.3168
# ...          ...      ...   ...                           ...
# 15477       5873     OECD  2019                     1259.5546
# 15478       5873     OECD  2020                     1273.4054
# 15479       5873     OECD  2021                     1261.6715
# 15480       5873     OECD  2030                           NaN
# 15481       5873     OECD  2050                           NaN
#
#        AFOLU_Emissions (CH4)  AFOLU_Emissions (CO2)  \
# 0                    28.2523               130.5921
# 1                    25.1645               130.5921
# 2                    24.8122               130.5921
# 3                    24.4821               130.5921
# 4                    24.4132               130.5921
# ...                      ...                    ...
# 15477             27422.7672           -431216.1060
# 15478             26807.1082           -430986.5039
# 15479             26791.0993           -430986.5039
# 15480                    NaN                    NaN
# 15481                    NaN                    NaN
#
#        AFOLU_Emissions (CO2eq) (AR5)  AFOLU_Emissions (CO2eq) from CH4 (AR5)  \
# 0                          1498.4820                                791.0644
# 1                          1325.0771                                704.6060
# 2                          1260.2782                                694.7416
# 3                          1245.5234                                685.4988
# 4                          1251.4647                                683.5696
# ...                              ...                                     ...
# 15477                    847348.4556                             767837.4816
# 15478                    822925.7537                             750599.0296
# 15479                    819435.4370                             750150.7804
# 15480                            NaN                                     NaN
# 15481                            NaN                                     NaN
#
#        AFOLU_Emissions (CO2eq) from N2O (AR5)  AFOLU_Emissions (N2O)  ...  \
# 0                                    576.8255                 2.1767  ...
# 1                                    489.8790                 1.8486  ...
# 2                                    434.9445                 1.6413  ...
# 3                                    429.4325                 1.6205  ...
# 4                                    437.3030                 1.6502  ...
# ...                                       ...                    ...  ...
# 15477                             510727.0800              1927.2720  ...
# 15478                             503313.2280              1899.2952  ...
# 15479                             500271.1605              1887.8157  ...
# 15480                                     NaN                    NaN  ...
# 15481                                     NaN                    NaN  ...
#
#        Synthetic Fertilizers_Emissions (CO2eq) (AR5)  \
# 0                                            82.7595
# 1                                            82.7595
# 2                                            38.6370
# 3                                            38.6370
# 4                                            44.1490
# ...                                              ...
# 15477                                    165811.4275
# 15478                                    170932.3405
# 15479                                    164611.7460
# 15480                                    154542.4350
# 15481                                    162786.0815
#
#        Synthetic Fertilizers_Emissions (CO2eq) from N2O (AR5)  \
# 0                                                82.7595
# 1                                                82.7595
# 2                                                38.6370
# 3                                                38.6370
# 4                                                44.1490
# ...                                                  ...
# 15477                                        165811.4275
# 15478                                        170932.3405
# 15479                                        164611.7460
# 15480                                        154542.4350
# 15481                                        162786.0815
#
#        Synthetic Fertilizers_Emissions (N2O)  \
# 0                                     0.3123
# 1                                     0.3123
# 2                                     0.1458
# 3                                     0.1458
# 4                                     0.1666
# ...                                      ...
# 15477                               625.7035
# 15478                               645.0277
# 15479                               621.1764
# 15480                               583.1790
# 15481                               614.2871
#
#        Synthetic Fertilizers_Indirect emissions (N2O)  Waste_Emissions (CH4)  \
# 0                                              0.0766                20.4000
# 1                                              0.0766                19.2000
# 2                                              0.0357                19.0000
# 3                                              0.0357                18.9000
# 4                                              0.0409                19.0000
# ...                                               ...                    ...
# 15477                                        153.4743             18384.0900
# 15478                                        158.2148             18150.8400
# 15479                                        152.3640             18239.9298
# 15480                                        143.0436                    NaN
# 15481                                        150.6742                    NaN
#
#        Waste_Emissions (CO2)  Waste_Emissions (CO2eq) (AR5)  \
# 0                        NaN                       606.9750
# 1                        NaN                       572.0500
# 2                        NaN                       567.2450
# 3                        NaN                       563.6500
# 4                        NaN                       567.2450
# ...                      ...                            ...
# 15477             12720.0427                    557452.2372
# 15478             12847.1362                    551146.9637
# 15479             12733.9931                    553793.5025
# 15480                    NaN                            NaN
# 15481                    NaN                            NaN
#
#        Waste_Emissions (CO2eq) from CH4 (AR5)  \
# 0                                    571.2000
# 1                                    537.6000
# 2                                    532.0000
# 3                                    529.2000
# 4                                    532.0000
# ...                                       ...
# 15477                             514754.5200
# 15478                             508223.5200
# 15479                             510718.0357
# 15480                                     NaN
# 15481                                     NaN
#
#        Waste_Emissions (CO2eq) from N2O (AR5)  Waste_Emissions (N2O)
# 0                                     35.7750                 0.1350
# 1                                     34.4500                 0.1300
# 2                                     35.2450                 0.1330
# 3                                     34.4500                 0.1300
# 4                                     35.2450                 0.1330
# ...                                       ...                    ...
# 15477                              29977.6745               113.1233
# 15478                              30076.3075               113.4955
# 15479                              30341.4737               114.4961
# 15480                                     NaN                    NaN
# 15481                                     NaN                    NaN
#
# [15482 rows x 252 columns]

# %% [markdown]
# # Alternativa para este caso en particular:
#
# La tabla final tendria 252 columnas (252 combinaciones de item y element). No nos interesa tantos datos de cada tabla.
#
# Pueden seleccionar todos los items pero solo 1 Element--->

# %%
# Extract all unique items and elements
unique_items = df['Item'].unique()
unique_elements = ['Emissions (CO2eq) (AR5)']

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(unique_elements)) & (df['Item'].isin(unique_items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %%
pivot_df
# Out:
#        Area Code     Area  Year  AFOLU_Emissions (CO2eq) (AR5)  \
# 0              1  Armenia  1992                      1498.4820
# 1              1  Armenia  1993                      1325.0771
# 2              1  Armenia  1994                      1260.2782
# 3              1  Armenia  1995                      1245.5234
# 4              1  Armenia  1996                      1251.4647
# ...          ...      ...   ...                            ...
# 15477       5873     OECD  2019                    847348.4556
# 15478       5873     OECD  2020                    822925.7537
# 15479       5873     OECD  2021                    819435.4370
# 15480       5873     OECD  2030                            NaN
# 15481       5873     OECD  2050                            NaN
#
#        Agricultural Soils_Emissions (CO2eq) (AR5)  \
# 0                                        544.8665
# 1                                        473.5815
# 2                                        418.9650
# 3                                        413.6385
# 4                                        423.1520
# ...                                           ...
# 15477                                 442412.5445
# 15478                                 447471.1560
# 15479                                 443311.3980
# 15480                                         NaN
# 15481                                         NaN
#
#        Agrifood Systems Waste Disposal_Emissions (CO2eq) (AR5)  \
# 0                                               250.1941
# 1                                               266.3624
# 2                                               282.6547
# 3                                               296.7981
# 4                                               301.4296
# ...                                                  ...
# 15477                                        263902.6370
# 15478                                        264319.9350
# 15479                                        264706.0607
# 15480                                                NaN
# 15481                                                NaN
#
#        Agrifood systems_Emissions (CO2eq) (AR5)  \
# 0                                  2.997345e+03
# 1                                  1.841726e+03
# 2                                  1.848546e+03
# 3                                  1.959937e+03
# 4                                  1.834244e+03
# ...                                         ...
# 15477                              3.512659e+06
# 15478                              3.438269e+06
# 15479                              3.530872e+06
# 15480                                       NaN
# 15481                                       NaN
#
#        All sectors with LULUCF_Emissions (CO2eq) (AR5)  \
# 0                                         8.467390e+03
# 1                                         4.911174e+03
# 2                                         5.031029e+03
# 3                                         5.648471e+03
# 4                                         4.824605e+03
# ...                                                ...
# 15477                                     1.491032e+07
# 15478                                     1.354679e+07
# 15479                                     1.414703e+07
# 15480                                              NaN
# 15481                                              NaN
#
#        All sectors without LULUCF_Emissions (CO2eq) (AR5)  \
# 0                                           8.335908e+03
# 1                                           4.779692e+03
# 2                                           4.899547e+03
# 3                                           5.516989e+03
# 4                                           4.693762e+03
# ...                                                  ...
# 15477                                       1.531582e+07
# 15478                                       1.395840e+07
# 15479                                       1.456847e+07
# 15480                                                NaN
# 15481                                                NaN
#
#        Burning - Crop residues_Emissions (CO2eq) (AR5)  ...  \
# 0                                               2.5811  ...
# 1                                               3.7940  ...
# 2                                               3.3673  ...
# 3                                               2.5027  ...
# 4                                               3.3953  ...
# ...                                                ...  ...
# 15477                                        7190.1476  ...
# 15478                                        7229.4692  ...
# 15479                                        7473.0049  ...
# 15480                                        7997.2677  ...
# 15481                                        8090.7054  ...
#
#        Manure left on Pasture_Emissions (CO2eq) (AR5)  \
# 0                                            402.8795
# 1                                            346.1695
# 2                                            340.8430
# 3                                            334.9335
# 4                                            334.5890
# ...                                               ...
# 15477                                     130154.6175
# 15478                                     129087.5420
# 15479                                     130200.9925
# 15480                                     146126.8035
# 15481                                     149433.6855
#
#        Net Forest conversion_Emissions (CO2eq) (AR5)  \
# 0                                            54.2254
# 1                                            54.2254
# 2                                            54.2254
# 3                                            54.2254
# 4                                            54.2254
# ...                                              ...
# 15477                                    209078.1220
# 15478                                    209078.1220
# 15479                                    209078.1220
# 15480                                            NaN
# 15481                                            NaN
#
#        On-farm energy use_Emissions (CO2eq) (AR5)  \
# 0                                        740.2164
# 1                                         93.0094
# 2                                         97.4503
# 3                                        114.9126
# 4                                        127.6139
# ...                                           ...
# 15477                                 257077.5152
# 15478                                 248882.1469
# 15479                                 250185.2035
# 15480                                         NaN
# 15481                                         NaN
#
#        Other_Emissions (CO2eq) (AR5)  \
# 0                            44.7850
# 1                            22.4720
# 2                             7.4200
# 3                             8.0295
# 4                             5.8565
# ...                              ...
# 15477                     44372.1198
# 15478                     43695.7280
# 15479                     45359.7342
# 15480                            NaN
# 15481                            NaN
#
#        Pesticides Manufacturing_Emissions (CO2eq) (AR5)  \
# 0                                                0.2283
# 1                                                0.1420
# 2                                                0.3406
# 3                                                0.3251
# 4                                                0.5378
# ...                                                 ...
# 15477                                        26935.6153
# 15478                                        16682.2414
# 15479                                        27791.1224
# 15480                                               NaN
# 15481                                               NaN
#
#        Pre- and Post- Production_Emissions (CO2eq) (AR5)  \
# 0                                           8.359032e+02
# 1                                           5.008966e+02
# 2                                           5.680747e+02
# 3                                           6.767576e+02
# 4                                           5.317826e+02
# ...                                                  ...
# 15477                                       1.535246e+06
# 15478                                       1.487048e+06
# 15479                                       1.572575e+06
# 15480                                                NaN
# 15481                                                NaN
#
#        Rice Cultivation_Emissions (CO2eq) (AR5)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 15477                                29642.7824
# 15478                                31723.9664
# 15479                                29532.1516
# 15480                                36129.8224
# 15481                                34591.7992
#
#        Savanna fires_Emissions (CO2eq) (AR5)  \
# 0                                     4.2975
# 1                                     4.2975
# 2                                     4.2975
# 3                                     4.2975
# 4                                     1.6016
# ...                                      ...
# 15477                             36366.6864
# 15478                             16128.9383
# 15479                             28670.1217
# 15480                                    NaN
# 15481                                    NaN
#
#        Synthetic Fertilizers_Emissions (CO2eq) (AR5)  \
# 0                                            82.7595
# 1                                            82.7595
# 2                                            38.6370
# 3                                            38.6370
# 4                                            44.1490
# ...                                              ...
# 15477                                    165811.4275
# 15478                                    170932.3405
# 15479                                    164611.7460
# 15480                                    154542.4350
# 15481                                    162786.0815
#
#        Waste_Emissions (CO2eq) (AR5)
# 0                           606.9750
# 1                           572.0500
# 2                           567.2450
# 3                           563.6500
# 4                           567.2450
# ...                              ...
# 15477                    557452.2372
# 15478                    551146.9637
# 15479                    553793.5025
# 15480                            NaN
# 15481                            NaN
#
# [15482 rows x 46 columns]

# %% [markdown]
# # A partir de aqui se pueden eliminar o retener las columnas que sean utiles

# %%
#new_file_name = file_name.split('.')[0]
#pivot_df.to_csv(rf'.\data\FAOSTAT\clean_data\country_tables\{new_file_name}_clean_groupby_country_year.csv')
