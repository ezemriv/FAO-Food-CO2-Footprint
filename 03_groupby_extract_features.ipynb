# %% [markdown]
# # Script para extraer datos utiles de cada tabla desde el formato zip directamente

# %%
import pandas as pd
#import numpy as np
import zipfile
#import io
import glob


#supress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Abrir el CSV dentro del zip file que incluye el patron "All_Data_" y guardarlo en un dataframe

# %%
# zip_path = r'.\data\FAOSTAT\all_raw\Emissions_Totals_E_All_Data_(Normalized).zip'

# %%
def read_CSV (numero):
    if numero < 10:
        numero = "0" + str(numero) # Añade un cero al principio si el número es menor a 10
    
    pattern = f"data//all_raw//{str(numero)}-*All_Data_(Normalized).zip"
    matching_files = glob.glob(pattern)
    
    if not matching_files:
        print("No existe el archivo")
        return None
 
    return matching_files[0] # Selecciona el primer archivo que coincida con el patrón

# %%
zip_path = read_CSV(26) # pasar el número de archivo que se quiere leer de "all_raw"    

# Initialize an empty DataFrame
df = pd.DataFrame()

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List all files in the zip archive
    all_files = zip_ref.namelist()
    print("Files in the zip archive:", all_files)
    
    # Iterate through the file names in the zip archive
    for file_name in all_files:
        # Check if the file name contains the pattern "All_Data_"
        if "All_Data_" in file_name and file_name.endswith(".csv"):
            print(f"Found matching file: {file_name}")
            # Read the CSV file into a DataFrame
            with zip_ref.open(file_name) as file:
                temp_df = pd.read_csv(file, encoding = "ISO-8859-1")
                # Concatenate the data from this CSV to the main DataFrame
                df = pd.concat([df, temp_df], ignore_index=True)
# Out:
# Files in the zip archive: ['Environment_LandUse_E_All_Data_(Normalized).csv', 'Environment_LandUse_E_AreaCodes.csv', 'Environment_LandUse_E_Flags.csv', 'Environment_LandUse_E_ItemCodes.csv']
# Found matching file: Environment_LandUse_E_All_Data_(Normalized).csv

# %% [markdown]
# ### Determinar si es una tabla de PAISES, COMIDAS, MIXTA o OTRAS
#
# (mirando bien creo que no hay tablas solo de comidas)

# %%
condition_paises = all(col in df.columns for col in ['Area Code', 'Year'])
condition_comida = df['Item'].isin(['Meat of chickens; fresh or chilled', 'Tapioca of cassava', 'Wheat', 'Barley', 'Cattle']).any()

if condition_paises and not condition_comida:
    print("La tabla parece ser SOLO de PAISES")
elif condition_comida and condition_paises:
    print("La tabla parece ser de COMIDAS (comidas, cultivos o animales) Y PAISES")
else:
    print("Ni idea que es esta tabla")
# Out:
# La tabla parece ser SOLO de PAISES

# %%
df.sample(10)
# Out:
#         Area Code Area Code (M49)                          Area  Item Code  \
# 8993           13            '048                       Bahrain       6655
# 57039          91            '328                        Guyana       6655
# 99874         169            '600                      Paraguay       6717
# 6126           10            '036                     Australia       6610
# 133533        231            '840      United States of America       6610
# 20935         115            '116                      Cambodia       6650
# 133447        215            '834   United Republic of Tanzania       6646
# 134590        240            '850  United States Virgin Islands       6620
# 39344          58            '218                       Ecuador       6650
# 81893         270            '175                       Mayotte       6655
#
#                                          Item  Element Code  \
# 8993    Land under perm. meadows and pastures          7208
# 57039   Land under perm. meadows and pastures          7209
# 99874           Naturally regenerating forest          7210
# 6126                        Agricultural land          7209
# 133533                      Agricultural land          7209
# 20935              Land under permanent crops          7208
# 133447                            Forest land          7209
# 134590                               Cropland          7277
# 39344              Land under permanent crops          7208
# 81893   Land under perm. meadows and pastures          7208
#
#                            Element  Year Code  Year    Unit    Value Flag
# 8993    Share in Agricultural land       1963  1963       %  57.1400    E
# 57039           Share in Land area       2020  2020       %   3.9700    E
# 99874         Share in Forest land       1995  1995       %  99.9200    E
# 6126            Share in Land area       1986  1986       %  60.9900    E
# 133533          Share in Land area       1967  1967       %  47.5300    E
# 20935   Share in Agricultural land       1970  1970       %   4.2700    E
# 133447          Share in Land area       2019  2019       %  52.1700    E
# 134590             Area per capita       2010  2010  ha/cap   0.0189    E
# 39344   Share in Agricultural land       1997  1997       %  17.4100    E
# 81893   Share in Agricultural land       1971  1971       %   0.1200    E

# %% [markdown]
# Ver las diferentes combinaciones de item y element que hay

# %%
pd.set_option('display.max_rows', None)
df.groupby(['Item',"Unit"])['Element'].value_counts().to_frame().sort_values(by = 'count', ascending=False)
# Out:
#                                                                          count
# Item                                  Unit   Element
# Agricultural land                     %      Share in Land area          14892
# Cropland                              %      Share in Agricultural land  14704
#                                              Share in Land area          14704
#                                       ha/cap Area per capita             14644
# Arable land                           %      Share in Agricultural land  14524
# Land under perm. meadows and pastures %      Share in Agricultural land  13835
#                                              Share in Land area          13835
# Land under permanent crops            %      Share in Agricultural land  13668
# Land area equipped for irrigation     %      Share in Agricultural land  11972
#                                              Share in Cropland           11972
# Forest land                           %      Share in Land area           8079
# Naturally regenerating forest         %      Share in Forest land         7523
# Planted Forest                        %      Share in Forest land         7523
# Agriculture area under organic agric. %      Share in Agricultural land   3060
# Agriculture area actually irrigated   %      Share in Agricultural land   1025

# %% [markdown]
# # Convertir tablas mediante "group by" y SUMANDO el valor para cada combinacion

# %% [markdown]
# ### Seleccionando elementos e items especificos
#
# Por ejemplo para esta tabla solo:
#
# Items: Enteric Fermentation, Agrifood systems
#
# Element: Emissions (CO2eq) (AR5)

# %%
# Define selected Elements and selected Items
selected_Items = ['Cropland']
selected_Elements = ["Share in Agricultural land", "Share in Land area", "Area per capita"]


# Filter the DataFrame
filtered_df = df[(df['Element'].isin(selected_Elements)) & (df['Item'].isin(selected_Items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element',"Unit"])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element',"Unit"], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %% [markdown]
# **El codigo genera una columna nueva para cada combinacion de item y element**

# %%
pd.reset_option('display.max_rows')
pivot_df
# Out:
#        Area Code     Area  Year  Cropland_Area per capita_ha/cap  \
# 0              1  Armenia  1992                           0.1403
# 1              1  Armenia  1993                           0.1466
# 2              1  Armenia  1994                           0.1523
# 3              1  Armenia  1995                           0.1535
# 4              1  Armenia  1996                           0.1597
# ...          ...      ...   ...                              ...
# 14699       5873     OECD  2016                              NaN
# 14700       5873     OECD  2017                              NaN
# 14701       5873     OECD  2018                              NaN
# 14702       5873     OECD  2019                              NaN
# 14703       5873     OECD  2020                              NaN
#
#        Cropland_Share in Agricultural land_%  Cropland_Share in Land area_%
# 0                                      41.28                          16.97
# 1                                      41.74                          17.32
# 2                                      41.67                          17.56
# 3                                      39.71                          17.35
# 4                                      38.74                          17.77
# ...                                      ...                            ...
# 14699                                  34.14                          11.34
# 14700                                  33.28                          11.33
# 14701                                  33.63                          11.30
# 14702                                  33.45                          11.28
# 14703                                  33.62                          11.27
#
# [14704 rows x 6 columns]

# %% [markdown]
# **Guardar tabla si queremos esta opcion**
#
# Sino continuar

# %%
#new_file_name = file_name.split('.')[0]
#pivot_df.to_csv(rf'.\data\FAOSTAT\clean_data\country_tables\{new_file_name}_clean_groupby_country_year.csv')

# %% [markdown]
# ### Seleccionando TODOS las combinaciones de item y element que hay

# %%
# Extract all unique items and elements
unique_items = df['Item'].unique()
unique_elements = df['Element'].unique()

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(unique_elements)) & (df['Item'].isin(unique_items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %%
pivot_df.shape
# Out:
# (14985, 18)

# %%
pivot_df
# Out:
#        Area Code     Area  Year  Agricultural land_Share in Land area  \
# 0              1  Armenia  1992                                 41.10
# 1              1  Armenia  1993                                 41.48
# 2              1  Armenia  1994                                 42.15
# 3              1  Armenia  1995                                 43.70
# 4              1  Armenia  1996                                 45.87
# ...          ...      ...   ...                                   ...
# 14980       5873     OECD  2016                                 33.21
# 14981       5873     OECD  2017                                 34.03
# 14982       5873     OECD  2018                                 33.62
# 14983       5873     OECD  2019                                 33.73
# 14984       5873     OECD  2020                                 33.52
#
#        Agriculture area actually irrigated_Share in Agricultural land  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14980                                                NaN
# 14981                                                NaN
# 14982                                                NaN
# 14983                                                NaN
# 14984                                                NaN
#
#        Agriculture area under organic agric._Share in Agricultural land  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14980                                               3.78
# 14981                                               4.48
# 14982                                               4.59
# 14983                                               4.67
# 14984                                               4.77
#
#        Arable land_Share in Agricultural land  Cropland_Area per capita  \
# 0                                       36.15                    0.1403
# 1                                       36.66                    0.1466
# 2                                       36.25                    0.1523
# 3                                       34.97                    0.1535
# 4                                       34.46                    0.1597
# ...                                       ...                       ...
# 14980                                   32.26                       NaN
# 14981                                   31.44                       NaN
# 14982                                   31.74                       NaN
# 14983                                   31.55                       NaN
# 14984                                   31.69                       NaN
#
#        Cropland_Share in Agricultural land  Cropland_Share in Land area  \
# 0                                    41.28                        16.97
# 1                                    41.74                        17.32
# 2                                    41.67                        17.56
# 3                                    39.71                        17.35
# 4                                    38.74                        17.77
# ...                                    ...                          ...
# 14980                                34.14                        11.34
# 14981                                33.28                        11.33
# 14982                                33.63                        11.30
# 14983                                33.45                        11.28
# 14984                                33.62                        11.27
#
#        Forest land_Share in Land area  \
# 0                               11.74
# 1                               11.74
# 2                               11.73
# 3                               11.72
# 4                               11.71
# ...                               ...
# 14980                           32.03
# 14981                           32.02
# 14982                           32.03
# 14983                           32.04
# 14984                           32.05
#
#        Land area equipped for irrigation_Share in Agricultural land  \
# 0                                                  23.59
# 1                                                  23.52
# 2                                                  23.30
# 3                                                  22.62
# 4                                                  21.68
# ...                                                  ...
# 14980                                               5.50
# 14981                                               5.38
# 14982                                               5.47
# 14983                                               5.48
# 14984                                               5.51
#
#        Land area equipped for irrigation_Share in Cropland  \
# 0                                                  57.14
# 1                                                  56.35
# 2                                                  55.92
# 3                                                  56.96
# 4                                                  55.97
# ...                                                  ...
# 14980                                              16.12
# 14981                                              16.18
# 14982                                              16.28
# 14983                                              16.38
# 14984                                              16.39
#
#        Land under perm. meadows and pastures_Share in Agricultural land  \
# 0                                                  58.72
# 1                                                  58.26
# 2                                                  58.33
# 3                                                  60.29
# 4                                                  61.26
# ...                                                  ...
# 14980                                              65.86
# 14981                                              66.72
# 14982                                              66.37
# 14983                                              66.55
# 14984                                              66.38
#
#        Land under perm. meadows and pastures_Share in Land area  \
# 0                                                  24.13
# 1                                                  24.17
# 2                                                  24.59
# 3                                                  26.34
# 4                                                  28.10
# ...                                                  ...
# 14980                                              21.87
# 14981                                              22.71
# 14982                                              22.31
# 14983                                              22.44
# 14984                                              22.25
#
#        Land under permanent crops_Share in Agricultural land  \
# 0                                                   5.13
# 1                                                   5.08
# 2                                                   5.42
# 3                                                   4.74
# 4                                                   4.29
# ...                                                  ...
# 14980                                               1.88
# 14981                                               1.85
# 14982                                               1.89
# 14983                                               1.90
# 14984                                               1.93
#
#        Naturally regenerating forest_Share in Forest land  \
# 0                                                  96.08
# 1                                                  96.17
# 2                                                  96.26
# 3                                                  96.35
# 4                                                  96.44
# ...                                                  ...
# 14980                                              89.37
# 14981                                              89.20
# 14982                                              89.14
# 14983                                              89.08
# 14984                                              89.02
#
#        Planted Forest_Share in Forest land
# 0                                     3.92
# 1                                     3.83
# 2                                     3.74
# 3                                     3.65
# 4                                     3.56
# ...                                    ...
# 14980                                10.63
# 14981                                10.80
# 14982                                10.86
# 14983                                10.92
# 14984                                10.98
#
# [14985 rows x 18 columns]

# %% [markdown]
# # Alternativa para este caso en particular:
#
# La tabla final tendria 252 columnas (252 combinaciones de item y element). No nos interesa tantos datos de cada tabla.
#
# Pueden seleccionar todos los items pero solo 1 Element--->

# %%
# Extract all unique items and elements
unique_items = df['Item'].unique()
unique_elements = ['Emissions (CO2eq) (AR5)']

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(unique_elements)) & (df['Item'].isin(unique_items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %%
pivot_df
# Out:
#        Area Code     Area  Year  AFOLU_Emissions (CO2eq) (AR5)  \
# 0              1  Armenia  1992                      1498.4820
# 1              1  Armenia  1993                      1325.0771
# 2              1  Armenia  1994                      1260.2782
# 3              1  Armenia  1995                      1245.5234
# 4              1  Armenia  1996                      1251.4647
# ...          ...      ...   ...                            ...
# 15477       5873     OECD  2019                    847348.4556
# 15478       5873     OECD  2020                    822925.7537
# 15479       5873     OECD  2021                    819435.4370
# 15480       5873     OECD  2030                            NaN
# 15481       5873     OECD  2050                            NaN
#
#        Agricultural Soils_Emissions (CO2eq) (AR5)  \
# 0                                        544.8665
# 1                                        473.5815
# 2                                        418.9650
# 3                                        413.6385
# 4                                        423.1520
# ...                                           ...
# 15477                                 442412.5445
# 15478                                 447471.1560
# 15479                                 443311.3980
# 15480                                         NaN
# 15481                                         NaN
#
#        Agrifood Systems Waste Disposal_Emissions (CO2eq) (AR5)  \
# 0                                               250.1941
# 1                                               266.3624
# 2                                               282.6547
# 3                                               296.7981
# 4                                               301.4296
# ...                                                  ...
# 15477                                        263902.6370
# 15478                                        264319.9350
# 15479                                        264706.0607
# 15480                                                NaN
# 15481                                                NaN
#
#        Agrifood systems_Emissions (CO2eq) (AR5)  \
# 0                                  2.997345e+03
# 1                                  1.841726e+03
# 2                                  1.848546e+03
# 3                                  1.959937e+03
# 4                                  1.834244e+03
# ...                                         ...
# 15477                              3.512659e+06
# 15478                              3.438269e+06
# 15479                              3.530872e+06
# 15480                                       NaN
# 15481                                       NaN
#
#        All sectors with LULUCF_Emissions (CO2eq) (AR5)  \
# 0                                         8.467390e+03
# 1                                         4.911174e+03
# 2                                         5.031029e+03
# 3                                         5.648471e+03
# 4                                         4.824605e+03
# ...                                                ...
# 15477                                     1.491032e+07
# 15478                                     1.354679e+07
# 15479                                     1.414703e+07
# 15480                                              NaN
# 15481                                              NaN
#
#        All sectors without LULUCF_Emissions (CO2eq) (AR5)  \
# 0                                           8.335908e+03
# 1                                           4.779692e+03
# 2                                           4.899547e+03
# 3                                           5.516989e+03
# 4                                           4.693762e+03
# ...                                                  ...
# 15477                                       1.531582e+07
# 15478                                       1.395840e+07
# 15479                                       1.456847e+07
# 15480                                                NaN
# 15481                                                NaN
#
#        Burning - Crop residues_Emissions (CO2eq) (AR5)  ...  \
# 0                                               2.5811  ...
# 1                                               3.7940  ...
# 2                                               3.3673  ...
# 3                                               2.5027  ...
# 4                                               3.3953  ...
# ...                                                ...  ...
# 15477                                        7190.1476  ...
# 15478                                        7229.4692  ...
# 15479                                        7473.0049  ...
# 15480                                        7997.2677  ...
# 15481                                        8090.7054  ...
#
#        Manure left on Pasture_Emissions (CO2eq) (AR5)  \
# 0                                            402.8795
# 1                                            346.1695
# 2                                            340.8430
# 3                                            334.9335
# 4                                            334.5890
# ...                                               ...
# 15477                                     130154.6175
# 15478                                     129087.5420
# 15479                                     130200.9925
# 15480                                     146126.8035
# 15481                                     149433.6855
#
#        Net Forest conversion_Emissions (CO2eq) (AR5)  \
# 0                                            54.2254
# 1                                            54.2254
# 2                                            54.2254
# 3                                            54.2254
# 4                                            54.2254
# ...                                              ...
# 15477                                    209078.1220
# 15478                                    209078.1220
# 15479                                    209078.1220
# 15480                                            NaN
# 15481                                            NaN
#
#        On-farm energy use_Emissions (CO2eq) (AR5)  \
# 0                                        740.2164
# 1                                         93.0094
# 2                                         97.4503
# 3                                        114.9126
# 4                                        127.6139
# ...                                           ...
# 15477                                 257077.5152
# 15478                                 248882.1469
# 15479                                 250185.2035
# 15480                                         NaN
# 15481                                         NaN
#
#        Other_Emissions (CO2eq) (AR5)  \
# 0                            44.7850
# 1                            22.4720
# 2                             7.4200
# 3                             8.0295
# 4                             5.8565
# ...                              ...
# 15477                     44372.1198
# 15478                     43695.7280
# 15479                     45359.7342
# 15480                            NaN
# 15481                            NaN
#
#        Pesticides Manufacturing_Emissions (CO2eq) (AR5)  \
# 0                                                0.2283
# 1                                                0.1420
# 2                                                0.3406
# 3                                                0.3251
# 4                                                0.5378
# ...                                                 ...
# 15477                                        26935.6153
# 15478                                        16682.2414
# 15479                                        27791.1224
# 15480                                               NaN
# 15481                                               NaN
#
#        Pre- and Post- Production_Emissions (CO2eq) (AR5)  \
# 0                                           8.359032e+02
# 1                                           5.008966e+02
# 2                                           5.680747e+02
# 3                                           6.767576e+02
# 4                                           5.317826e+02
# ...                                                  ...
# 15477                                       1.535246e+06
# 15478                                       1.487048e+06
# 15479                                       1.572575e+06
# 15480                                                NaN
# 15481                                                NaN
#
#        Rice Cultivation_Emissions (CO2eq) (AR5)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 15477                                29642.7824
# 15478                                31723.9664
# 15479                                29532.1516
# 15480                                36129.8224
# 15481                                34591.7992
#
#        Savanna fires_Emissions (CO2eq) (AR5)  \
# 0                                     4.2975
# 1                                     4.2975
# 2                                     4.2975
# 3                                     4.2975
# 4                                     1.6016
# ...                                      ...
# 15477                             36366.6864
# 15478                             16128.9383
# 15479                             28670.1217
# 15480                                    NaN
# 15481                                    NaN
#
#        Synthetic Fertilizers_Emissions (CO2eq) (AR5)  \
# 0                                            82.7595
# 1                                            82.7595
# 2                                            38.6370
# 3                                            38.6370
# 4                                            44.1490
# ...                                              ...
# 15477                                    165811.4275
# 15478                                    170932.3405
# 15479                                    164611.7460
# 15480                                    154542.4350
# 15481                                    162786.0815
#
#        Waste_Emissions (CO2eq) (AR5)
# 0                           606.9750
# 1                           572.0500
# 2                           567.2450
# 3                           563.6500
# 4                           567.2450
# ...                              ...
# 15477                    557452.2372
# 15478                    551146.9637
# 15479                    553793.5025
# 15480                            NaN
# 15481                            NaN
#
# [15482 rows x 46 columns]

# %% [markdown]
# # A partir de aqui se pueden eliminar o retener las columnas que sean utiles

# %%
#new_file_name = file_name.split('.')[0]
#pivot_df.to_csv(rf'.\data\FAOSTAT\clean_data\country_tables\{new_file_name}_clean_groupby_country_year.csv')
