# %% [markdown]
# # Script para extraer datos utiles de cada tabla desde el formato zip directamente

# %%
import pandas as pd
#import numpy as np
import zipfile
#import io
import glob


#supress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Abrir el CSV dentro del zip file que incluye el patron "All_Data_" y guardarlo en un dataframe

# %%
# se comenta porque toma el zip de la funcion read_CSV
# zip_path = r'.\data\FAOSTAT\all_raw\Emissions_Totals_E_All_Data_(Normalized).zip'

# %%
def read_CSV (numero):
    if numero < 10:
        numero = "0" + str(numero) # Añade un cero al principio si el número es menor a 10
    
    pattern = f"data//FAOSTAT//all_raw//{str(numero)}-*All_Data_(Normalized).zip"
    matching_files = glob.glob(pattern)
    
    if not matching_files:
        print("No existe el archivo")
        return None
 
    return matching_files[0] # Selecciona el primer archivo que coincida con el patrón

# %%
zip_path = read_CSV(17) # pasar el número de archivo que se quiere leer de "all_raw"    

# Initialize an empty DataFrame
df = pd.DataFrame()

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List all files in the zip archive
    all_files = zip_ref.namelist()
    print("Files in the zip archive:", all_files)
    
    # Iterate through the file names in the zip archive
    for file_name in all_files:
        # Check if the file name contains the pattern "All_Data_"
        if "All_Data_" in file_name and file_name.endswith(".csv"):
            print(f"Found matching file: {file_name}")
            # Read the CSV file into a DataFrame
            with zip_ref.open(file_name) as file:
                temp_df = pd.read_csv(file, encoding = "ISO-8859-1")
                # Concatenate the data from this CSV to the main DataFrame
                df = pd.concat([df, temp_df], ignore_index=True)
# Out:
# Files in the zip archive: ['Emissions_Pre_Post_Production_E_All_Data_(Normalized).csv', 'Emissions_Pre_Post_Production_E_AreaCodes.csv', 'Emissions_Pre_Post_Production_E_Flags.csv']
# Found matching file: Emissions_Pre_Post_Production_E_All_Data_(Normalized).csv

# %% [markdown]
# ### Determinar si es una tabla de PAISES, COMIDAS, MIXTA o OTRAS
#
# (mirando bien creo que no hay tablas solo de comidas)

# %%
condition_paises = all(col in df.columns for col in ['Area Code', 'Year'])
condition_comida = df['Item'].isin(['Meat of chickens; fresh or chilled', 'Tapioca of cassava', 'Wheat', 'Barley', 'Cattle']).any()

if condition_paises and not condition_comida:
    print("La tabla parece ser SOLO de PAISES")
elif condition_comida and condition_paises:
    print("La tabla parece ser de COMIDAS (comidas, cultivos o animales) Y PAISES")
else:
    print("Ni idea que es esta tabla")
# Out:
# La tabla parece ser SOLO de PAISES

# %%
df.sample(2)
# Out:
#         Area Code Area Code (M49)               Area  Item Code  \
# 452627       5400            '150             Europe       6506
# 122448         61            '226  Equatorial Guinea       6500
#
#                                          Item  Element Code  \
# 452627                         Food Packaging          7273
# 122448  Energy Use (Pre- and Post-Production)        723113
#
#                         Element  Year Code  Year Unit         Value Flag
# 452627          Emissions (CO2)       1991  1991   kt  43882.504845    E
# 122448  Emissions (CO2eq) (AR5)       2007  2007   kt     74.418882    E

# %% [markdown]
# Ver las diferentes combinaciones de item y element que hay

# %%
pd.set_option('display.max_rows', None)
df.groupby(['Item',"Element"])["Unit"].value_counts().to_frame().sort_values(by = 'Item', ascending=True)
# Out:
#                                                                                     count
# Item                                  Element                                 Unit
# Agrifood Systems Waste Disposal       Emissions (CH4)                         kt     8407
#                                       Emissions (CO2)                         kt     4589
#                                       Emissions (CO2eq) (AR5)                 kt     8407
#                                       Emissions (N2O)                         kt     8014
# Cold Chain F-Gas                      Emissions (CO2eq) from F-gases (AR5)    kt     7472
# Domestic Wastewater                   Emissions (CH4)                         kt     7797
#                                       Emissions (CO2eq) (AR5)                 kt     7893
#                                       Emissions (N2O)                         kt     6650
# Energy Use (Pre- and Post-Production) Energy Use (Total)                      TJ     7299
#                                       Energy Use (Natural Gas, including LNG) TJ     4158
#                                       Energy Use (Heat)                       TJ     2032
#                                       Energy Use (Electricity)                TJ     7232
#                                       Emissions (N2O)                         kt     8435
#                                       Emissions (CO2eq) (AR5)                 kt     8435
#                                       Emissions (CO2)                         kt     8435
#                                       Emissions (CH4)                         kt     8435
#                                       Energy Use (Coal)                       TJ     3444
# Fertilizers Manufacturing             Emissions (CO2)                         kt     3557
#                                       Emissions (CO2eq) (AR5)                 kt     3581
#                                       Emissions (N2O)                         kt     2521
# Food Household Consumption            Energy Use (Electricity)                TJ     7169
#                                       Energy Use (Total)                      TJ     7230
#                                       Energy Use (Natural Gas, including LNG) TJ     3550
#                                       Energy Use (Coal)                       TJ     2542
#                                       Emissions (CH4)                         kt     7835
#                                       Emissions (CO2eq) from F-gases (AR5)    kt     4702
#                                       Emissions (CO2eq) (AR5)                 kt     8080
#                                       Emissions (CO2)                         kt     7835
#                                       Emissions (N2O)                         kt     7835
# Food Packaging                        Energy Use (Total)                      TJ     4646
#                                       Energy Use (Natural Gas, including LNG) TJ     3644
#                                       Energy Use (Heat)                       TJ     1734
#                                       Energy Use (Electricity)                TJ     4061
#                                       Energy Use (Coal)                       TJ     2835
#                                       Emissions (CO2eq) (AR5)                 kt     5037
#                                       Emissions (CO2)                         kt     5037
#                                       Emissions (CH4)                         kt     5037
#                                       Emissions (N2O)                         kt     5037
# Food Processing                       Energy Use (Heat)                       TJ     1728
#                                       Energy Use (Total)                      TJ     3666
#                                       Energy Use (Natural Gas, including LNG) TJ     2863
#                                       Energy Use (Electricity)                TJ     3549
#                                       Energy Use (Coal)                       TJ     2305
#                                       Emissions (CO2eq) from F-gases (AR5)    kt     1994
#                                       Emissions (CO2eq) (AR5)                 kt     4171
#                                       Emissions (CO2)                         kt     3949
#                                       Emissions (CH4)                         kt     3949
#                                       Emissions (N2O)                         kt     3949
# Food Retail                           Emissions (CO2eq) from F-gases (AR5)    kt     7472
#                                       Emissions (CH4)                         kt     7314
#                                       Emissions (CO2)                         kt     7314
#                                       Emissions (CO2eq) (AR5)                 kt     7911
#                                       Emissions (N2O)                         kt     7314
#                                       Energy Use (Coal)                       TJ     2546
#                                       Energy Use (Electricity)                TJ     6991
#                                       Energy Use (Heat)                       TJ     1952
#                                       Energy Use (Natural Gas, including LNG) TJ     3266
#                                       Energy Use (Total)                      TJ     7043
# Food Transport                        Energy Use (Natural Gas, including LNG) TJ     2860
#                                       Energy Use (Total)                      TJ     3254
#                                       Emissions (N2O)                         kt     8130
#                                       Energy Use (Coal)                       TJ     1963
#                                       Emissions (CO2eq) (AR5)                 kt     8255
#                                       Emissions (CO2)                         kt     8130
#                                       Emissions (CH4)                         kt     8130
#                                       Emissions (CO2eq) from F-gases (AR5)    kt     3441
# Incineration                          Emissions (CO2)                         kt     4589
#                                       Emissions (CO2eq) (AR5)                 kt     4589
# Industrial Wastewater                 Emissions (CH4)                         kt     8056
#                                       Emissions (CO2eq) (AR5)                 kt     8056
#                                       Emissions (N2O)                         kt     8014
# Pesticides Manufacturing              Emissions (N2O)                         kt     7730
#                                       Emissions (CO2eq) (AR5)                 kt     7730
#                                       Emissions (CH4)                         kt     7730
#                                       Emissions (CO2)                         kt     7730
# Pre- and Post- Production             Energy Use (Natural Gas, including LNG) TJ     4158
#                                       Emissions (CH4)                         kt     8642
#                                       Emissions (CO2)                         kt     8537
#                                       Emissions (CO2eq) (AR5)                 kt     8642
#                                       Emissions (CO2eq) from F-gases (AR5)    kt     7472
#                                       Emissions (N2O)                         kt     8499
#                                       Energy Use (Coal)                       TJ     3444
#                                       Energy Use (Electricity)                TJ     7232
#                                       Energy Use (Heat)                       TJ     2032
#                                       Energy Use (Total)                      TJ     7299
# Solid Food Waste                      Emissions (CH4)                         kt     6922
#                                       Emissions (CO2eq) (AR5)                 kt     6922

# %%
pd.set_option('display.max_rows', None)
df.groupby(["Element",'Item'])["Unit"].value_counts().to_frame().sort_values(by = ['Element','Item'], ascending=True)
# Out:
#                                                                                     count
# Element                                 Item                                  Unit
# Emissions (CH4)                         Agrifood Systems Waste Disposal       kt     8407
#                                         Domestic Wastewater                   kt     7797
#                                         Energy Use (Pre- and Post-Production) kt     8435
#                                         Food Household Consumption            kt     7835
#                                         Food Packaging                        kt     5037
#                                         Food Processing                       kt     3949
#                                         Food Retail                           kt     7314
#                                         Food Transport                        kt     8130
#                                         Industrial Wastewater                 kt     8056
#                                         Pesticides Manufacturing              kt     7730
#                                         Pre- and Post- Production             kt     8642
#                                         Solid Food Waste                      kt     6922
# Emissions (CO2)                         Agrifood Systems Waste Disposal       kt     4589
#                                         Energy Use (Pre- and Post-Production) kt     8435
#                                         Fertilizers Manufacturing             kt     3557
#                                         Food Household Consumption            kt     7835
#                                         Food Packaging                        kt     5037
#                                         Food Processing                       kt     3949
#                                         Food Retail                           kt     7314
#                                         Food Transport                        kt     8130
#                                         Incineration                          kt     4589
#                                         Pesticides Manufacturing              kt     7730
#                                         Pre- and Post- Production             kt     8537
# Emissions (CO2eq) (AR5)                 Agrifood Systems Waste Disposal       kt     8407
#                                         Domestic Wastewater                   kt     7893
#                                         Energy Use (Pre- and Post-Production) kt     8435
#                                         Fertilizers Manufacturing             kt     3581
#                                         Food Household Consumption            kt     8080
#                                         Food Packaging                        kt     5037
#                                         Food Processing                       kt     4171
#                                         Food Retail                           kt     7911
#                                         Food Transport                        kt     8255
#                                         Incineration                          kt     4589
#                                         Industrial Wastewater                 kt     8056
#                                         Pesticides Manufacturing              kt     7730
#                                         Pre- and Post- Production             kt     8642
#                                         Solid Food Waste                      kt     6922
# Emissions (CO2eq) from F-gases (AR5)    Cold Chain F-Gas                      kt     7472
#                                         Food Household Consumption            kt     4702
#                                         Food Processing                       kt     1994
#                                         Food Retail                           kt     7472
#                                         Food Transport                        kt     3441
#                                         Pre- and Post- Production             kt     7472
# Emissions (N2O)                         Agrifood Systems Waste Disposal       kt     8014
#                                         Domestic Wastewater                   kt     6650
#                                         Energy Use (Pre- and Post-Production) kt     8435
#                                         Fertilizers Manufacturing             kt     2521
#                                         Food Household Consumption            kt     7835
#                                         Food Packaging                        kt     5037
#                                         Food Processing                       kt     3949
#                                         Food Retail                           kt     7314
#                                         Food Transport                        kt     8130
#                                         Industrial Wastewater                 kt     8014
#                                         Pesticides Manufacturing              kt     7730
#                                         Pre- and Post- Production             kt     8499
# Energy Use (Coal)                       Energy Use (Pre- and Post-Production) TJ     3444
#                                         Food Household Consumption            TJ     2542
#                                         Food Packaging                        TJ     2835
#                                         Food Processing                       TJ     2305
#                                         Food Retail                           TJ     2546
#                                         Food Transport                        TJ     1963
#                                         Pre- and Post- Production             TJ     3444
# Energy Use (Electricity)                Energy Use (Pre- and Post-Production) TJ     7232
#                                         Food Household Consumption            TJ     7169
#                                         Food Packaging                        TJ     4061
#                                         Food Processing                       TJ     3549
#                                         Food Retail                           TJ     6991
#                                         Pre- and Post- Production             TJ     7232
# Energy Use (Heat)                       Energy Use (Pre- and Post-Production) TJ     2032
#                                         Food Packaging                        TJ     1734
#                                         Food Processing                       TJ     1728
#                                         Food Retail                           TJ     1952
#                                         Pre- and Post- Production             TJ     2032
# Energy Use (Natural Gas, including LNG) Energy Use (Pre- and Post-Production) TJ     4158
#                                         Food Household Consumption            TJ     3550
#                                         Food Packaging                        TJ     3644
#                                         Food Processing                       TJ     2863
#                                         Food Retail                           TJ     3266
#                                         Food Transport                        TJ     2860
#                                         Pre- and Post- Production             TJ     4158
# Energy Use (Total)                      Energy Use (Pre- and Post-Production) TJ     7299
#                                         Food Household Consumption            TJ     7230
#                                         Food Packaging                        TJ     4646
#                                         Food Processing                       TJ     3666
#                                         Food Retail                           TJ     7043
#                                         Food Transport                        TJ     3254
#                                         Pre- and Post- Production             TJ     7299

# %% [markdown]
# # Convertir tablas mediante "group by" y SUMANDO el valor para cada combinacion

# %% [markdown]
# ### Seleccionando elementos e items especificos
#
# Por ejemplo para esta tabla solo:
#
# Items: Enteric Fermentation, Agrifood systems
#
# Element: Emissions (CO2eq) (AR5)

# %%
# Define selected Elements and selected Items
selected_Items = ['Total Energy']
selected_Elements = ["Emissions (CO2)", "Emissions (CH4)", "Emissions (N2O)", "Energy use in agriculture"]

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(selected_Elements)) & (df['Item'].isin(selected_Items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element',"Unit"])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element',"Unit"], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %% [markdown]
# **El codigo genera una columna nueva para cada combinacion de item y element**

# %%
pd.reset_option('display.max_rows')
pivot_df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[127], line 2
#       1 pd.reset_option('display.max_rows')
# ----> 2 pivot_df.sample(5)
#
# File c:\Users\afernandez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6118, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6115 if weights is not None:
#    6116     weights = sample.preprocess_weights(self, weights, axis)
# -> 6118 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6119 result = self.take(sampled_indices, axis=axis)
#    6121 if ignore_index:
#
# File c:\Users\afernandez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
#     154 )
#
# File numpy\\random\\mtrand.pyx:945, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %% [markdown]
# **Guardar tabla si queremos esta opcion**
#
# Sino continuar

# %%
new_file_name = file_name.split('.')[0]
print(new_file_name)
# pivot_df.to_csv(rf'.\data\FAOSTAT\clean_data\country_tables\{new_file_name}_clean_groupby_country_year.csv')
# Out:
# Emissions_Agriculture_Energy_E_Flags

# %% [markdown]
# ### Seleccionando TODOS las combinaciones de item y element que hay

# %%
# Extract all unique items and elements
unique_items = df['Item'].unique()
unique_elements = df['Element'].unique()

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(unique_elements)) & (df['Item'].isin(unique_items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %%
pivot_df.head(2)
pivot_df[pivot_df["Area Code"]==5000].to_csv("prueba_tabla_18.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[101], line 2
#       1 pivot_df.head(2)
# ----> 2 pivot_df[pivot_df["Area Code"]==5000].to_csv("prueba_tabla_18.csv")
#
# File c:\Users\afernandez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\afernandez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\afernandez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\afernandez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\afernandez\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'prueba_tabla_18.csv'

# %% [markdown]
# # Alternativa para este caso en particular:
#
# La tabla final tendria 252 columnas (252 combinaciones de item y element). No nos interesa tantos datos de cada tabla.
#
# Pueden seleccionar todos los items pero solo 1 Element--->

# %%
# Extract all unique items and elements
unique_items = df['Item'].unique()
unique_elements = ['Emissions (CO2eq) (AR5)']

# Filter the DataFrame
filtered_df = df[(df['Element'].isin(unique_elements)) & (df['Item'].isin(unique_items))]

# Group by Area, Year, Item, and Element, then sum the values
grouped = filtered_df.groupby(['Area Code', 'Area', 'Year', 'Item', 'Element'])['Value'].sum().reset_index()

# Pivot the table to have combinations of Items and Elements as columns
pivot_df = grouped.pivot_table(index=['Area Code', 'Area', 'Year'], 
                               columns=['Item', 'Element'], 
                               values='Value', 
                               aggfunc='sum').reset_index()

# Flatten the multi-level column index and rename columns
pivot_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in pivot_df.columns.values]

# %%
pivot_df
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Year]
# Index: []

# %% [markdown]
# # A partir de aqui se pueden eliminar o retener las columnas que sean utiles

# %%
#new_file_name = file_name.split('.')[0]
#pivot_df.to_csv(rf'.\data\FAOSTAT\clean_data\country_tables\{new_file_name}_clean_groupby_country_year.csv')

# %%
# TODO mandar la tabla con el numero de encabezado a la carpeta de "clean_data" con el nombre de "numero_clean_groupby_country_year.csv"
