# %%
import pandas as pd
import numpy as np

# %%
path = r"..\data\FAOSTAT\production_datasets"
path
# Out:
# '..\\data\\FAOSTAT\\production_datasets'

# %%
prod_df = pd.read_csv(f"{path}\\sample_Production_Crops_Livestock_E_All_Data_(Normalized).csv")

# %%
prod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area Code        1000 non-null   int64
#  1   Area Code (M49)  1000 non-null   object
#  2   Area             1000 non-null   object
#  3   Item Code        1000 non-null   int64
#  4   Item Code (CPC)  1000 non-null   object
#  5   Item             1000 non-null   object
#  6   Element Code     1000 non-null   int64
#  7   Element          1000 non-null   object
#  8   Year Code        1000 non-null   int64
#  9   Year             1000 non-null   int64
#  10  Unit             1000 non-null   object
#  11  Value            1000 non-null   float64
#  12  Flag             1000 non-null   object
#  13  Note             20 non-null     object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 109.5+ KB

# %%
prod_df.Flag.value_counts(normalize=True)
# Out:
# Flag
# E    0.440
# A    0.428
# I    0.077
# M    0.029
# X    0.026
# Name: proportion, dtype: float64

# %%
prod_df[~prod_df['Note'].isnull()]
# Out:
#      Area Code Area Code (M49)                        Area  Item Code  \
# 53         102            '364  Iran (Islamic Republic of)        236
# 85         158            '562                       Niger        211
# 104        185            '643          Russian Federation        619
# 141         56            '214          Dominican Republic       1043
# 206        170            '604                        Peru        894
# 218        185            '643          Russian Federation        558
# 221        113            '417                  Kyrgyzstan        372
# 297        136            '478                  Mauritania         83
# 347        249            '887                       Yemen        919
# 513        234            '858                     Uruguay        122
# 555        101            '360                   Indonesia        156
# 595        154            '807             North Macedonia        995
# ...

# %%
prod_df['Area'].unique()
# Out:
# array(['China, Taiwan Province of', 'Australia and New Zealand',
#        'Switzerland', 'Peru', "Democratic People's Republic of Korea",
#        'United Arab Emirates', 'Finland', 'Sri Lanka', 'Eswatini',
#        'Israel', 'United States of America', 'Eastern Africa',
#        'Middle Africa', 'Albania', 'Mexico', 'South America', 'Iraq',
#        'Uzbekistan', 'Guatemala', 'Southern Europe',
#        'Venezuela (Bolivarian Republic of)', 'Benin', 'India', 'Türkiye',
#        'Afghanistan', 'Land Locked Developing Countries', 'Nigeria',
#        'Chad', 'Americas', 'Nicaragua', 'Bangladesh', 'World',
#        'Western Europe', 'Least Developed Countries', 'Qatar', 'Greece',
#        'Norway', 'Tunisia',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'China, Hong Kong SAR', 'Kenya', 'Ukraine', 'Togo', 'Saudi Arabia',
#        "Lao People's Democratic Republic", 'Africa', 'Europe', 'Brazil',
# ...
